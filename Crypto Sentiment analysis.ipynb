# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()


load_dotenv(dotenv_path='C:/Users/saif_/OneDrive/Desktop/APIkeys.env.txt')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\saif_\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Read your api key environment variable
from newsapi import NewsApiClient
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_articles = newsapi.get_everything(q="Bitcoin", language="en", sort_by="relevancy")
bitcoin_articles
# Out:
# {'status': 'ok',
#  'totalResults': 7331,
#  'articles': [{'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Gian M. Volpicelli',
#    'title': 'The Rise and Fall of a Bitcoin Mining Sensation',
#    'description': 'Compass Mining grew quickly during crypto’s halcyon days. Now, its customers and their thousands of mining machines are stuck.',
#    'url': 'https://www.wired.com/story/compass-mining-bitcoin-russia/',
#    'urlToImage': 'https://media.wired.com/photos/62e9c5e1d7368105da057de3/191:100/w_1280,c_limit/BitRiver-Mining-Center-Rise-And-Fall-Of-Bitcoin-Mining-Business-1184520941.jpg',
#    'publishedAt': '2022-08-03T11:00:00Z',
#    'content': "It was 8:45 in the morning of June 13 when Bill Stewart, the CEO of Maine-based bitcoin mining business Dynamics Mining, received a call from one of his employees. He's like, Every machine inside of … [+3472 chars]"},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Lily Hay Newman, Andy Greenberg',
#    'title': 'Bitcoin Fog Case Could Put Cryptocurrency Tracing on Trial',
#    'description': 'Roman Sterlingov, accused of laundering $336 million, is proclaiming his innocence—and challenging a key investigative tool.',
#    'url': 'https://www.wired.com/story/bitcoin-fog-roman-sterlingov-blockchain-analysis/',
#    'urlToImage': 'https://media.wired.com/photos/62e95bada1dc74857a858363/191:100/w_1280,c_limit/Bitcoin-Fog-Security-GettyImages-1241143235.jpg',
#    'publishedAt': '2022-08-02T22:02:13Z',
#    'content': 'Tools to trace cryptocurrencies have, over just the last several years, allowed law enforcement agencies to convict dark web black market administrators, recover millions in ransomware payments, seiz… [+3510 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Barr',
#    'title': 'Bitcoin Dumpster Guy Has a Wild Plan to Rescue Millions in Bitcoin From a Landfill',
#    'description': 'You gotta hand it to some people for being impetuous even in the face of extraordinary odds. Imagine looking for a single hard drive amidst a literal heap of trash. Well, that’s been one UK man’s goal for nearly a decade after he accidentally lost the chance …',
#    'url': 'https://gizmodo.com/bitcoin-landfill-crypto-boston-dynamics-1849327709',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/6574aac0667df42205f65f11603c4df1.jpg',
#    'publishedAt': '2022-07-25T18:45:00Z',
#    'content': 'You gotta hand it to some people for being impetuous even in the face of extraordinary odds. Imagine looking for a single hard drive amidst a literal heap of trash. Well, thats been one UK mans goal … [+4091 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Mariella Moon',
#    'title': 'Putin signs law prohibiting crypto payments in Russia',
#    'description': 'People in Russia will soon no longer be allowed to use digital assets as a form of payment. Russian president Vladimir Putin has signed a bill into law prohibiting the use of digital assets, such as cryptocurrency and NFTs, to pay for goods and services. In a…',
#    'url': 'https://www.engadget.com/putin-law-prohibiting-crypto-payments-russia-125015139.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-10/da24dc60-287b-11ec-bdfb-1b79f92db31c',
#    'publishedAt': '2022-07-16T12:50:15Z',
#    'content': 'People in Russia will soon no longer be allowed to use digital assets as a form of payment. Russian president Vladimir Putin has signed a bill into law prohibiting the use of digital assets, such as … [+1436 chars]'},
#   {'source': {'id': None, 'name': 'News18'},
#    'author': 'Business Desk',
#    'title': 'Tesla Sells 75% of its Bitcoin Holdings, Elon Musk Says No Dogecoin Sold by Company - News18',
#    'description': '<ol><li>Tesla Sells 75% of its Bitcoin Holdings, Elon Musk Says No Dogecoin Sold by Company\xa0\xa0News18\r\n</li><li>Bitcoin Recovers: Tesla says it sold 75% of Bitcoin Holdings | Business News | World News\xa0\xa0WION\r\n</li><li>Tesla sells majority of its Bitcoin holding…',
#    'url': 'https://www.news18.com/news/business/cryptocurrency/tesla-sells-75-of-its-bitcoin-holdings-elon-musk-says-no-dogecoin-sold-by-company-5594401.html',
#    'urlToImage': 'https://images.news18.com/ibnlive/uploads/2022/06/tesla-ceo-elon-musk-ians-165588526116x9.jpg',
#    'publishedAt': '2022-07-21T05:05:01Z',
#    'content': 'Elon Musk-owned electric vehicle making company Tesla has sold a significant amount of its Bitcoin holdings, the firm said in a statement. Reporting its earnings for Q2, the company said that it had … [+2850 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Crypto weekly: Bitcoin breaks freefall - Reuters',
#    'description': 'From Bitcoin highs to blockchain bridge lows, to why some of the worlds biggest technology companies are freezing jobs, we round up the week’s big stories in the world of virtual money. Kristy Kilburn reports.',
#    'url': 'https://www.reuters.com/video/watch/idOV602802082022RP1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20220802&i=OV602802082022RP1&r=OV602802082022RP1&t=2',
#    'publishedAt': '2022-08-02T21:21:55Z',
#    'content': 'Posted \r\nFrom Bitcoin highs to blockchain bridge lows, to why some of the worlds biggest technology companies are freezing jobs, we round up the weeks big stories in the world of virtual money. Krist… [+17 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin rises 6.9% to $22717 - Reuters',
#    'description': 'Bitcoin rose 6.85% to $22,717.05 at 22:05 GMT on Wednesday, adding $1,457.27 to its previous close.',
#    'url': 'https://www.reuters.com/technology/bitcoin-rises-69-22717-2022-07-27/',
#    'urlToImage': 'https://www.reuters.com/resizer/eeQb8FK8oNm7KlzdFaYT9lvuJ5s=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/LP3EEKNH25PZXG4NK2TOEKO2VY.jpg',
#    'publishedAt': '2022-07-27T22:15:00Z',
#    'content': "July 27 (Reuters) - Bitcoin rose 6.85% to $22,717.05 at 22:05 GMT on Wednesday, adding $1,457.27 to its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is up 29.1% from t… [+352 chars]"},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Bill Chappell',
#    'title': 'Tesla cashes out $936 million in Bitcoin, after a year of crypto turbulence',
#    'description': 'Tesla aggressively embraced Bitcoin in 2021, investing $1.5 billion in the currency. But it now says its profitability was affected by "Bitcoin impairment."',
#    'url': 'https://www.npr.org/2022/07/21/1112689091/bitcoin-tesla-selloff',
#    'urlToImage': 'https://media.npr.org/assets/img/2022/07/21/gettyimages-1301068355_wide-6e1fb52dc7dad5da5b4ac664ac6f13b9e3c60200.jpg?s=1400',
#    'publishedAt': '2022-07-21T15:56:30Z',
#    'content': 'What a difference a year makes. After making big plays in Bitcoin in 2021, Tesla jettisoned $936 million worth of the cryptocurrency in the second quarter of 2022, trimming its Bitcoin holdings by 75… [+1974 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Carla Mozée)',
#    'title': "Bitcoin rises 4% to retake $24,000 as investors shift to risk-on ahead of this week's inflation report",
#    'description': "Bitcoin has trimmed this year's loss to roughly 50%. A decline in US Treasury yields has aided bitcoin as the cryptocurrency offers no yield.",
#    'url': 'https://markets.businessinsider.com/news/currencies/bitcoin-price-cryptocurrencies-24000-markets-inflation-yields-fed-powell-cpi-2022-8',
#    'urlToImage': 'https://i.insider.com/62b042ec4245600018dda5b4?width=1200&format=jpeg',
#    'publishedAt': '2022-08-08T17:47:50Z',
#    'content': 'Bitcoin advanced to $24,000 for the first time in August, a move taking place before financial markets assess a high-profile reading of US inflation this week.\xa0\r\nBitcoin rose as much as 4% to $24,191… [+1770 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Cryptoverse: Bitcoin beats the heat in a jumpin' July - Reuters",
#    'description': "It's been a good month for bitcoin - and we haven't said that for a while.",
#    'url': 'https://www.reuters.com/technology/cryptoverse-bitcoin-beats-heat-jumpin-july-2022-08-02/',
#    'urlToImage': 'https://www.reuters.com/resizer/SUiQzSC61VNz4Ok30YOCbvAFg88=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/HZTIOIS3NZNIDHH7HUT62Y42IA.jpg',
#    'publishedAt': '2022-08-02T05:12:00Z',
#    'content': "Aug 2 (Reuters) - It's been a good month for bitcoin - and we haven't said that for a while.\r\nAfter months of freefall, it jumped more than 17% in July, its best performance since October. Ether rose… [+3538 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin rises 3.4% to $24584; up 39.7% from year low in June - Reuters',
#    'description': 'Bitcoin rose 3.36% to $24,584.24 at 1707 GMT on Saturday, adding $798.93 to its previous close.',
#    'url': 'https://www.reuters.com/technology/bitcoin-rises-34-24584-up-397-year-low-june-2022-07-30/',
#    'urlToImage': 'https://www.reuters.com/resizer/olDHRm0jmk0gc_1U1JwzC8ItOzY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/KGBQSYSMQRO47BZLCENBDEJYZA.jpg',
#    'publishedAt': '2022-07-30T17:21:00Z',
#    'content': "July 30 (Reuters) - Bitcoin rose 3.36% to $24,584.24 at 1707 GMT on Saturday, adding $798.93 to its previous close.\r\nBitcoin, the world's biggest, best-known cryptocurrency, is up 39.7% from the year… [+345 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Lauren Leffer',
#    'title': "Tesla's Profits Decline for the First Time in Over a Year",
#    'description': 'Tesla released its 2022 Q2 earnings Wednesday and the results are mixed: Elon Musk’s electric vehicle maker reported $2.3 billion in second-quarter profit, down from a record $3.3 billion in the first quarter of 2022. That’s the company’s first sequential dec…',
#    'url': 'https://gizmodo.com/tesla-bitcoin-q2-earnings-elon-musk-1849201112',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/c5fc515d4388dd37e3c3442f5b2f13f3.jpg',
#    'publishedAt': '2022-07-20T22:00:00Z',
#    'content': 'Tesla released its 2022 Q2 earnings Wednesday and the results are mixed: Elon Musks electric vehicle maker reported $2.3 billion in second-quarter profit, down from a record $3.3 billion in the first… [+3324 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Simon Chandler)',
#    'title': 'How a Bitcoin wallet gives you more security and control over your digital assets',
#    'description': 'A Bitcoin wallet is a software program that allows you to transfer and store bitcoin. It comes as either hardware or software, with hardware wallets offering the most security.',
#    'url': 'https://www.businessinsider.com/personal-finance/bitcoin-wallet',
#    'urlToImage': 'https://i.insider.com/60706d0ba451820019b3a3e1?width=1200&format=jpeg',
#    'publishedAt': '2022-08-11T21:19:33Z',
#    'content': '"Not your keys, not your coin" is a popular saying within some parts of the cryptocurrency community. It\'s a reminder that if you choose to store your bitcoin on a cryptocurrency exchange account, th… [+7518 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'BlackRock launches spot bitcoin private trust for U.S. clients - Reuters',
#    'description': 'BlackRock Inc <a href="https://www.reuters.com/companies/BLK.N" target="_blank">(BLK.N)</a>, the world\'s biggest asset manager, has launched a spot bitcoin private trust for institutional clients in the United States, according to a blog post on its website.',
#    'url': 'https://www.reuters.com/technology/blackrock-launches-spot-bitcoin-private-trust-us-clients-2022-08-11/',
#    'urlToImage': 'https://www.reuters.com/resizer/dm3gxxy55l135TSvy6WVVBxoBMo=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/RW5HROCP6NNKXKM3TSRKNQRYSQ.jpg',
#    'publishedAt': '2022-08-11T13:49:00Z',
#    'content': "Aug 11 (Reuters) - BlackRock Inc (BLK.N), the world's biggest asset manager, has launched a spot bitcoin private trust for institutional clients in the United States, according to a blog post on its … [+1171 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Cryptoverse-Holding your breath for a bitcoin bounce - Reuters',
#    'description': "If you're waiting for a bitcoin recovery, you may have to sweat it out for months. That's the conclusion of some technical specialists seeking method from the madness.",
#    'url': 'https://www.reuters.com/technology/cryptoverse-holding-your-breath-bitcoin-bounce-2022-07-19/',
#    'urlToImage': 'https://www.reuters.com/resizer/TP89RCVUE8u_CZJQPAFBTdtyTYg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/7AUPLFQJA5PQ7GNVOE2QVVIFZ4.jpg',
#    'publishedAt': '2022-07-19T05:16:00Z',
#    'content': "July 19 (Reuters) - If you're waiting for a bitcoin recovery, you may have to sweat it out for months. That's the conclusion of some technical specialists seeking method from the madness.\r\nBitcoin's … [+3397 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin briefly falls after Tesla says it sold 75% of its holdings - Reuters',
#    'description': 'Bitcoin stumbled late on Wednesday after Tesla Inc <a href="https://www.reuters.com/companies/TSLA.O" target="_blank">(TSLA.O)</a> said it converted about 75% of its purchases of the virtual token into fiat currency.',
#    'url': 'https://www.reuters.com/markets/us/bitcoin-falls-after-tesla-says-it-converted-75-bitcoin-purchases-into-fiat-2022-07-20/',
#    'urlToImage': 'https://www.reuters.com/resizer/zFzr92lQ-tAivImOMcKmKkOyeQo=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/OYI5A7HGWNMSVJ4OPQTETGT5ZY.jpg',
#    'publishedAt': '2022-07-20T21:37:00Z',
#    'content': "NEW YORK, July 20 (Reuters) - Bitcoin stumbled late on Wednesday after Tesla Inc (TSLA.O) said it converted about 75% of its purchases of the virtual token into fiat currency.\r\nThe world's largest cr… [+1274 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'tlevin@insider.com (Tim Levin)',
#    'title': 'Tesla has cashed-out most of its bad bitcoin bet',
#    'description': 'Tesla is all but abandoning its massive bitcoin investment as cryptocurrencies continue to take a dive.',
#    'url': 'https://www.businessinsider.com/tesla-bitcoin-converted-to-fiat-crypto-crash-elon-musk-2022-7',
#    'urlToImage': 'https://i.insider.com/62d863dc0c98f500195ebfa3?width=1200&format=jpeg',
#    'publishedAt': '2022-07-20T20:37:53Z',
#    'content': 'Tesla seems to be abandoning its ten-figure bitcoin bet amid a severe slump in cryptocurrency markets.\xa0\r\nThe electric-car maker said on Wednesday that it has sold approximately 75% of its bitcoin as … [+1260 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Igor Bonifacic',
#    'title': 'Democratic lawmakers want federal regulators to track crypto mining energy use and emissions',
#    'description': 'Congressional Democrats are calling on the Environmental Protection Agency and Department of Energy to address the recent proliferation of cryptocurrency mining within the US. In a letter\r\n sent Friday (via The Guardian\r\n), Senator Elizabeth Warren and five o…',
#    'url': 'https://www.engadget.com/democratic-lawmakers-want-crypto-miners-to-disclose-energy-use-emissions-214551420.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-images/2018-10/bb685100-d07f-11e8-bce9-0ff7742a351d',
#    'publishedAt': '2022-07-17T21:45:51Z',
#    'content': 'Congressional Democrats are calling on the Environmental Protection Agency and Department of Energy to address the recent proliferation of cryptocurrency mining within the US. In a letter\r\n sent Frid… [+2231 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Honduras launches 'Bitcoin Valley' in the tourist town of Santa Lucia - Reuters.com",
#    'description': 'People can pay for a slushie with crypto in the streets of "Bitcoin Valley," a project in the Honduran tourist enclave of Santa Lucia through which the country has entered the digital currency trend.',
#    'url': 'https://www.reuters.com/world/americas/honduras-launches-bitcoin-valley-tourist-town-santa-lucia-2022-07-29/',
#    'urlToImage': 'https://www.reuters.com/resizer/jPZytgVrBXWFzrPY9IVzSoBkS6w=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/4ZHVPFZ4KJJITKXCQMIMCUFRDM.jpg',
#    'publishedAt': '2022-07-29T19:46:00Z',
#    'content': 'July 29 (Reuters) - People can pay for a slushie with crypto in the streets of "Bitcoin Valley," a project in the Honduran tourist enclave of Santa Lucia through which the country has entered the dig… [+2277 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern',
#    'title': 'I’m no longer making predictions about cryptocurrency. Here’s why',
#    'description': 'If you’d bought or sold bitcoin every time I wrote about it over the last decade, how much would you have made? Let’s do the maths<ul><li>Don’t get TechScape delivered to your inbox? Sign up here</li></ul>I’ve been writing about cryptocurrency for my entire c…',
#    'url': 'https://amp.theguardian.com/technology/2022/aug/03/techscape-bitcoin-cryptocurrency-predictions',
#    'urlToImage': 'https://i.guim.co.uk/img/media/47c0e67fc97c6e8f15012744ac879ce0918cad9e/46_319_3487_2092/master/3487.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=59218b55d3e48d92b1ab13f378cbf129',
#    'publishedAt': '2022-08-03T10:45:25Z',
#    'content': 'Ive been writing about cryptocurrency for my entire career. In that time, one point Ive always stuck to is simple: dont listen to me for investment advice. Today, I want to quantify why.\r\nBitcoin was… [+7658 chars]'},
#   {'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Allison Dretzin',
#    'title': 'The Relationship between Bitcoin and Inflation',
#    'description': 'Speculation is that some investors have turned to bitcoin in order to protect their holdings from the impacts of hyperinflation. But what exactly does that mean? People are drawn to everything they can run to in order to protect themselves from inflation, whi…',
#    'url': 'https://readwrite.com/the-relationship-between-bitcoin-and-inflation/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2022/07/Bitcoin-and-Inflation.jpg',
#    'publishedAt': '2022-07-23T15:01:20Z',
#    'content': 'Speculation is that some investors have turned to bitcoin in order to protect their holdings from the impacts of hyperinflation. But what exactly does that mean?\r\nPeople are drawn to everything they … [+8199 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': 'El Salvador aims to avoid default with $1.6 billion bond buyback as the nation caps off its first year with bitcoin as official currency',
#    'description': 'Since the Central America nation adopted bitcoin as legal tender last September, its bonds have traded at steep discounts.',
#    'url': 'https://markets.businessinsider.com/news/bonds/el-salvador-bitcoin-default-debt-bond-buyback-bukele-nayib-currency-2022-7',
#    'urlToImage': 'https://i.insider.com/61e1786a7c6a200018420bb5?width=1200&format=jpeg',
#    'publishedAt': '2022-07-27T12:50:02Z',
#    'content': 'El Salvador announced Tuesday it would move to buy back $1.6 billion in its own bonds as it attempts to steer away from a default.\r\nSince the Central America nation adopted bitcoin as legal tender la… [+1907 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Carla Mozée)',
#    'title': 'Michael Saylor to step down as MicroStrategy CEO as the software maker records $917 million charge on bitcoin investment',
#    'description': "Saylor will become executive chairman at MicroStrategy and will focus more on the company's bitcoin acquisition strategy.",
#    'url': 'https://markets.businessinsider.com/news/currencies/microstrategy-bitcoin-michael-saylor-ceo-917-million-impairment-charge-crypto-022-8',
#    'urlToImage': 'https://i.insider.com/60ca262123393a00188e3872?width=1200&format=jpeg',
#    'publishedAt': '2022-08-03T13:37:24Z',
#    'content': "MicroStrategy's founder Michael Saylor will step down as CEO, with the move coming after the enterprise software maker took a quarterly impairment charge of more than $900 million related to the drop… [+1552 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': "Ether has rallied 50% over the last month, blowing past bitcoin's gains, ahead of 'merge' for Ethereum 2.0",
#    'description': 'Bitcoin — the biggest cryptocurrency by market cap — is up about 16.6% from a month ago, trading around $23,296 on Friday.',
#    'url': 'https://markets.businessinsider.com/news/currencies/ethereum-price-today-eth-beats-btc-up-50-percent-merge-2022-7',
#    'urlToImage': 'https://i.insider.com/62dace98d001100019100561?width=1200&format=jpeg',
#    'publishedAt': '2022-07-22T16:40:44Z',
#    'content': 'Over the last month, ether has significantly outperformed bitcoin as enthusiasm grows ahead of the highly anticipated "merge" event for Ethereum 2.0.\r\nThe second-largest cryptocurrency was hovering a… [+1359 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Davíd Lavie)',
#    'title': "Bitcoin halving is how the supply of the world's largest cryptocurrency is controlled",
#    'description': 'Bitcoin halving is when the rate of new bitcoins entering circulation is cut in half, which occurs approximately every four years.',
#    'url': 'https://www.businessinsider.com/personal-finance/bitcoin-halving',
#    'urlToImage': 'https://i.insider.com/619d45c2d2fd62001820b8d0?width=1200&format=jpeg',
#    'publishedAt': '2022-08-16T16:59:51Z',
#    'content': "Despite its somewhat nebulous-seeming nature, Bitcoin is a finite resource. There will only ever be 21 million Bitcoin. So far, 19 million have already been mined, meaning there's just two million Bi… [+6317 chars]"},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Julia Horowitz, CNN Business',
#    'title': 'Netflix finally told investors what they want to hear. Now comes the hard part',
#    'description': "It wasn't long ago that Wall Street would have bristled at such grim news out of Netflix: Between April and June, the company lost 970,000 subscribers.",
#    'url': 'https://www.cnn.com/2022/07/20/investing/premarket-stocks-trading/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/220720073624-01-netflix-on-tablet-file-super-tease.jpg',
#    'publishedAt': '2022-07-20T12:18:47Z',
#    'content': "A version of this story first appeared in CNN Business' Before the Bell newsletter. Not a subscriber? You can sign up\xa0right here. You can listen to an audio version of the newsletter by clicking the … [+6882 chars]"},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Andrew Couts',
#    'title': 'The US Emergency Alert System Has Dangerous Flaws',
#    'description': 'Plus: A crypto-heist extravaganza, a peek at an NSO spyware dashboard, and more.',
#    'url': 'https://www.wired.com/story/fema-emergency-alert-flaws-security-roundup/',
#    'urlToImage': 'https://media.wired.com/photos/62edb7e154d910713ee4f20c/191:100/w_1280,c_limit/US-Emergency-Alert-System-Security-GettyImages-1166460347.jpg',
#    'publishedAt': '2022-08-06T13:00:00Z',
#    'content': 'Cryptocurrency tracing has become a key tool for police investigating everything from fraud and ransomware to child abuse. But its accuracy may soon be put to the test.\r\nThis week, we reported on new… [+5333 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "DOJ demands more insight into Celsius' severance payments, bitcoin sales - Reuters.com",
#    'description': "The U.S. Department of Justice has demanded more court oversight of Celsius Networks' plans to make employee severance payments and to sell bitcoins during the cryptocurrency lender's bankruptcy.",
#    'url': 'https://www.reuters.com/legal/litigation/doj-demands-more-insight-into-celsius-severance-payments-bitcoin-sales-2022-08-10/',
#    'urlToImage': 'https://www.reuters.com/resizer/ALN_nDjg-snAvii2TknPvulz5FU=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/5IQLPL77JBKSXIUM6RJR5PHKRE.jpg',
#    'publishedAt': '2022-08-10T23:11:00Z',
#    'content': "(Reuters) - The U.S. Department of Justice has demanded more court oversight of Celsius Networks' plans to make employee severance payments and to sell bitcoins during the cryptocurrency lender's ban… [+3074 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Katie Canales)',
#    'title': "The crypto winter has come for Jack Dorsey's company, Block",
#    'description': 'The ex-Twitter CEO\'s digital payments firm reported a fall in revenue due to bitcoin\'s slumped price and "broader uncertainty" in the crypto world.',
#    'url': 'https://www.businessinsider.com/crypto-winter-impacts-jack-dorsey-block-earnings-cash-app-2022-8',
#    'urlToImage': 'https://i.insider.com/600f0ea0cf23090019e97248?width=1200&format=jpeg',
#    'publishedAt': '2022-08-05T15:40:12Z',
#    'content': "No one's safe from the beating that the crypto market is taking, including noted bitcoin maximalist Jack Dorsey.\r\nThe founder and ex-CEO of Twitter turned more of his attention to his digital payment… [+1912 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'MicroStrategy Reports $1 Billion Loss, CEO Steps Down To Focus On Bitcoin',
#    'description': "MicroStrategy co-founder Michael Saylor gave up his chief executive officer title and said he'll focus more on Bitcoin after the enterprise-software maker reported a loss of more than $1 billion related to the second-quarter plunge in the price of the cryptoc…",
#    'url': 'https://slashdot.org/story/22/08/02/2341234/microstrategy-reports-1-billion-loss-ceo-steps-down-to-focus-on-bitcoin',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/business_64.png',
#    'publishedAt': '2022-08-03T01:25:00Z',
#    'content': 'Saylor, who founded the Tysons Corner, Virginia-based company in 1989, will continue to serve as executive chairman as retains its Bitcoin buying strategy. MicroStrategy President Phong Le will take … [+922 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'embargo Brazil crypto exchange Mercado Bitcoin to expand into Mexico this year, says CEO - Reuters.com',
#    'description': 'SoftBank-backed Brazilian crypto exchange Mercado Bitcoin is set to enter the Mexican market by the end of the year, as part of a plan to expand elsewhere in Latin America, its chief executive told Reuters.',
#    'url': 'https://www.reuters.com/technology/embargo-brazil-crypto-exchange-mercado-bitcoin-expand-into-mexico-this-year-says-2022-07-21/',
#    'urlToImage': 'https://www.reuters.com/resizer/BzhS_X9Nu3m2XIiyOv18TUJ-UGs=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/MOKWOWGGQZIB5AFQ6OST3EGAZY.jpg',
#    'publishedAt': '2022-07-21T13:32:00Z',
#    'content': 'SAO PAULO, July 21 (Reuters) - SoftBank-backed Brazilian crypto exchange Mercado Bitcoin is set to enter the Mexican market by the end of the year, as part of a plan to expand elsewhere in Latin Amer… [+1967 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Texas bitcoin miners back online after power surge caused curtailments - Reuters',
#    'description': 'Large-scale bitcoin mining operations in Texas are back online after sweltering temperatures that caused electricity use to spike led to power curtailments earlier in the month, an industry group said on Tuesday.',
#    'url': 'https://www.reuters.com/business/finance/texas-bitcoin-miners-back-online-after-power-surge-caused-curtailments-2022-07-19/',
#    'urlToImage': 'https://www.reuters.com/resizer/YZaO2XwcWJgJQByh00F69Puj_QQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/YBGBAX5GA5NTHDPPFOT6R27WAI.jpg',
#    'publishedAt': '2022-07-19T20:38:00Z',
#    'content': 'NEW YORK, July 19 (Reuters) - Large-scale bitcoin mining operations in Texas are back online after sweltering temperatures that caused electricity use to spike led to power curtailments earlier in th… [+1077 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Crypto platform Zipmex to start releasing Bitcoin, Ether for customers - Reuters',
#    'description': 'Crypto exchange Zipmex will release Ethereum and Bitcoin tokens from this week, a spokesperson said on Monday, allowing 60% of its customers to retrieve their digital assets after a suspension of withdrawals from its Z Wallet product.',
#    'url': 'https://www.reuters.com/technology/crypto-platform-zipmex-start-releasing-bitcoin-ether-customers-2022-08-08/',
#    'urlToImage': 'https://www.reuters.com/resizer/Fd5a-BznMketgq1x6iGznPIbLTM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/DAQG47AXNNNY5CJY7EM4QCRX6Q.jpg',
#    'publishedAt': '2022-08-08T10:29:00Z',
#    'content': 'BANGKOK, Aug 8 (Reuters) - Crypto exchange Zipmex will release Ethereum and Bitcoin tokens from this week, a spokesperson said on Monday, allowing 60% of its customers to retrieve their digital asset… [+874 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Crypto Weekly: Tesla sells its stash - Reuters.com',
#    'description': 'From Elon Musk changing a big bitcoin stash into regular cash, to a crypto adventure in the Central African Republic, we round up the big stories in virtual money. Kristy Kilburn reports.',
#    'url': 'https://www.reuters.com/video/watch/idOV455026072022RP1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20220726&i=OV455026072022RP1&r=OV455026072022RP1&t=2',
#    'publishedAt': '2022-07-26T19:54:58Z',
#    'content': 'Posted \r\nFrom Elon Musk changing a big bitcoin stash into regular cash, to a crypto adventure in the Central African Republic, we round up the big stories in virtual money. Kristy Kilburn reports.'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Carla Mozée)',
#    'title': 'Block slides as drop in bitcoin revenue dents 2nd-quarter earnings for the Cash App parent',
#    'description': "Bitcoin's price dropped by nearly 60% during the second quarter but has recovered slightly to trade above $23,000.",
#    'url': 'https://markets.businessinsider.com/news/stocks/block-stock-price-bitcoin-crypto-revenue-charge-cashapp-market-btc-dorsey-2022-8',
#    'urlToImage': 'https://i.insider.com/62491315e22adb0018d1c24c?width=1200&format=jpeg',
#    'publishedAt': '2022-08-05T14:13:09Z',
#    'content': "Block shares fell Friday after the payments processing company took a second-quarter impairment charge related to bitcoin's crash during the so-called crypto winter for digital assets.\xa0\r\nShares fell … [+1689 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Katie Canales)',
#    'title': "Bitso's $2 billion rise shows the power of crypto innovation in Latin America",
#    'description': 'Bitso "paved the way for much of the crypto ecosystem in Latin America," one expert said, and helped drive El Salvador\'s bitcoin experiment.',
#    'url': 'https://www.businessinsider.com/bitso-crypto-exchange-mexico-latin-america-profile-2022-7',
#    'urlToImage': 'https://i.insider.com/62d8081c38d0b5001995aefb?width=1200&format=jpeg',
#    'publishedAt': '2022-07-20T21:38:41Z',
#    'content': "El Salvador has famously been rolling out a crypto wallet to the nation's 6.5 million citizens. The digital wallet is run in part by a startup in Mexico called Bitso, whose name is a mash-up of bitco… [+4849 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'bevans@insider.com (Brian Evans)',
#    'title': "Coinbase will help BlackRock's top clients gain exposure to the cryptocurrency market in a new partnership",
#    'description': 'The partnership will initially be limited to bitcoin exposure, according to a Coinbase blog post. Shares of the exchange jumped as much as 21% early Thursday.',
#    'url': 'https://markets.businessinsider.com/news/currencies/coinbase-blackrock-partnership-digital-asset-news-crypto-bitcoin-markets-inflation-2022-8',
#    'urlToImage': 'https://i.insider.com/62ebc8ab05c1fd001846fdaa?width=1200&format=jpeg',
#    'publishedAt': '2022-08-04T14:24:15Z',
#    'content': "Coinbase is partnering with BlackRock to help some of the asset manager's top clients gain greater exposure to cryptocurrencies.\xa0\r\nThe world's largest asset manager tapped Coinbase in a move that mar… [+1154 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'tmohamed@businessinsider.com (Theron Mohamed)',
#    'title': "Elon Musk dumped 75% of Tesla's bitcoin last quarter, and wants out of his deal to buy Twitter. Plunging asset prices and recession fears may explain why",
#    'description': 'Musk may be having second thoughts as Tesla, Twitter, and bitcoin have plunged in value this year, and the US economy is hurtling towards a recession.',
#    'url': 'https://markets.businessinsider.com/news/stocks/elon-musk-tesla-bitcoin-price-sales-twitter-deal-recession-economy-2022-7',
#    'urlToImage': 'https://i.insider.com/62d922ff0c98f500195eca2d?width=1200&format=jpeg',
#    'publishedAt': '2022-07-21T10:35:36Z',
#    'content': "Elon Musk, who's currently trying to back out of buying Twitter, revealed on Wednesday that Tesladumped 75% of its bitcoin holdings last quarter. The mercurial tech billionaire has offered excuses, b… [+3730 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'A rally in bitcoin and ether push crypto market cap back above $1 trillion as digital assets struggle against bear market',
#    'description': 'Investor sentiment often follows price, so if the rally in bitcoin and ether can hold, it should lure more investors back into the crypto space.',
#    'url': 'https://markets.businessinsider.com/news/currencies/crypto-market-bitcoin-ether-rally-market-value-1-trillion-coinbase-2022-7',
#    'urlToImage': 'https://i.insider.com/62d58c07aac2aa0018cb9d57?width=1200&format=jpeg',
#    'publishedAt': '2022-07-18T17:34:05Z',
#    'content': "A big rally in both bitcoin and ether on Monday helped drive the cryptocurrency market value back above the $1 trillion threshold for the first time since June 13.\r\nMonday's gains should be a welcome… [+1982 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Simon Chandler)',
#    'title': 'How to invest in blockchain, the high-risk but high-potential technology behind bitcoin and other digital transactions',
#    'description': 'Investing in blockchain technology has become hot due to its role in bitcoin and other promising developments for its use. Here are ways to invest.',
#    'url': 'https://www.businessinsider.com/personal-finance/how-to-invest-in-blockchain-technology',
#    'urlToImage': 'https://i.insider.com/5ff4f229d184b30018aad332?width=1200&format=jpeg',
#    'publishedAt': '2022-07-29T20:26:39Z',
#    'content': 'Bitcoin often dominates the financial news, riveting investors with its volatile price swings and appreciation potential. Getting far less attention, though, is blockchain, the database technology on… [+10653 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mturner@businessinsider.com (Matt Turner,Jordan Parker Erb,Ben Tobin,Lisa Ryan)',
#    'title': 'How Walmart is trying to solve its excessive-inventory issues',
#    'description': "Today we're kicking things off with a look at Walmart's excessive-inventory issues, then a look at return-to-office orders, a bitcoin mission, and more.",
#    'url': 'https://www.businessinsider.com/walmart-memo-inventory-price-drop-profit-summer-inflation-2022-7',
#    'urlToImage': 'https://i.insider.com/62e42a454b455800188b68ff?width=1200&format=jpeg',
#    'publishedAt': '2022-07-31T12:00:00Z',
#    'content': "Hi, I'm Matt Turner, the editor in chief of business at Insider. Welcome back to Insider Weekly, a roundup of some of our top stories.\xa0\r\nOn the agenda today:\r\nBefore we get started: Ben Tobin, our re… [+4343 chars]"},
#   {'source': {'id': None, 'name': 'eMarketer'},
#    'author': 'insider@insider.com (Adriana Nunez)',
#    'title': 'Block slows investment, hiring after mixed Q2 but plays up growth initiatives',
#    'description': "Block's gross payment volume surged 23% YoY in Q2—but total net revenues dropped 6% YoY as a result of Bitcoin losses.",
#    'url': 'https://www.emarketer.com/content/block-slows-investment-hiring-after-mixed-q2-plays-up-growth-initiatives',
#    'urlToImage': 'https://contentstorage-nax1.emarketer.com/4e404a766a2b47b726ddb320cf0f2b59/default-image-share.png?im=FitAndFill,width=1200,height=630',
#    'publishedAt': '2022-08-08T13:28:05Z',
#    'content': 'The data: Blocks gross payment volume (GPV) increased 23% year over year (YoY) in Q2, a slowdown from 88% YoY growth during the same period last year, per\r\n its shareholder letter. However, total net… [+2569 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Dan Milmo Global technology editor',
#    'title': 'Another court case fails to unlock the mystery of bitcoin’s Satoshi Nakamoto',
#    'description': 'As Craig Wright’s legal tussles pile up, the world is no closer to knowing who the currency’s inventor really isWho is Satoshi Nakamoto? The mysterious inventor of bitcoin is a renowned figure in the world of cryptocurrency but his true identity is unknown.Ho…',
#    'url': 'https://amp.theguardian.com/technology/2022/aug/06/another-court-case-fails-to-unlock-the-mystery-of-bitcoins-satoshi-nakamoto',
#    'urlToImage': 'https://i.guim.co.uk/img/media/5e754634d68931ac0ba3ae191be4dba3a14c20b9/0_371_3500_2100/master/3500.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=3e2bcabf223f0e7bb598dd3d9d37b22a',
#    'publishedAt': '2022-08-06T09:00:11Z',
#    'content': 'Who is Satoshi Nakamoto? The mysterious inventor of bitcoin is a renowned figure in the world of cryptocurrency but his true identity is unknown.\r\nHowever, the British blogger Peter McCormack was cer… [+5606 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Dorsey-led Block posts loss for second quarter on bitcoin slump - Reuters',
#    'description': 'Jack Dorsey-led Block Inc <a href="https://www.reuters.com/companies/SQ.N" target="_blank">(SQ.N)</a> on Thursday reported a loss for the second quarter as a bruising selloff in cryptocurrency markets hurt the fintech company\'s earnings from bitcoin trades on…',
#    'url': 'https://www.reuters.com/technology/dorsey-led-block-posts-loss-second-quarter-2022-08-04/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=106',
#    'publishedAt': '2022-08-04T20:37:00Z',
#    'content': "Aug 4 (Reuters) - Jack Dorsey-led Block Inc (SQ.N) on Thursday reported a loss for the second quarter as a bruising selloff in cryptocurrency markets hurt the fintech company's earnings from bitcoin … [+879 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Block shares slip after crypto winter dampens quarterly results - Reuters',
#    'description': 'Shares of Jack Dorsey-led Block Inc <a href="https://www.reuters.com/companies/SQ.N" target="_blank">(SQ.N)</a>, a digital payments firm that has bet big on bitcoin, declined nearly 7% in premarket trading on Friday after the company reported a loss in quarte…',
#    'url': 'https://www.reuters.com/technology/block-shares-slip-after-crypto-winter-dampens-quarterly-results-2022-08-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/SMSA0eNWtPIR-Mx2xNcRc0QEqpI=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/PA7ZOH5NSRPU7IQAMPPAGLSBFA.jpg',
#    'publishedAt': '2022-08-05T11:14:00Z',
#    'content': 'Aug 5 (Reuters) - Shares of Jack Dorsey-led Block Inc (SQ.N), a digital payments firm that has bet big on bitcoin, declined nearly 7% in premarket trading on Friday after the company reported a loss … [+1944 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Theron Mohamed',
#    'title': "Elon Musk Dumped 75% of Tesla's Bitcoin Last Quarter, and Wants Out of His Deal to Buy Twitter. Plunging Asset Prices and Recession Fears May Explain Why",
#    'description': 'The Tesla CEO is also trying to renege on his $44 billion agreement to buy Twitter.',
#    'url': 'https://www.entrepreneur.com/article/431874',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1658413095-elon.jpg',
#    'publishedAt': '2022-07-21T14:05:00Z',
#    'content': "Elon Musk, who's currently trying to back out of buying Twitter, revealed on Wednesday that Tesladumped 75% of its bitcoin holdings last quarter. The mercurial tech billionaire has offered excuses, b… [+3542 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Jea Yu',
#    'title': 'Is it Time to Throw in the Towel On Coinbase Stock?',
#    'description': 'Cryptocurrency trading marketplace Coinbase (NASDAQ: COIN) stock triggered a short squeeze on its horrendous Q2 2022 earnings report.',
#    'url': 'https://www.entrepreneur.com/article/433472',
#    'urlToImage': 'https://assets.entrepreneur.com/providers/marketbeat/hero-image-marketbeat-433472.jpeg',
#    'publishedAt': '2022-08-16T05:00:00Z',
#    'content': 'Cryptocurrency trading marketplace Coinbase (NASDAQ: COIN) stock triggered a short squeeze on its horrendous Q2 2022 earnings report. Shares are still down (-66%) for the year even after more than do… [+5677 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'jsor@insider.com (Jennifer Sor)',
#    'title': "Bitcoin bull Mike Novogratz says crypto's forced deleveraging is over and bitcoin is still an asset to hold amid economic uncertainty",
#    'description': '"The worst is over. There is no more forced deleveraging that\'s going to happen," the famed crypto investor told CNBC.',
#    'url': 'https://markets.businessinsider.com/news/currencies/bitcoin-mike-novogratz-crypto-outlook-crash-deleveraging-cycle-ethereum-merge-2022-8',
#    'urlToImage': 'https://i.insider.com/62f111c28677d80018ee50fd?width=1200&format=jpeg',
#    'publishedAt': '2022-08-10T16:46:31Z',
#    'content': 'Billionaire bitcoin bull Mike Novogratz believes the forced deleveraging of the cryptocurrency market is over and that investors can expect new narratives to shape the space following a brutal quarte… [+1750 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': 'El Salvador still has plans for a bitcoin bond even as the country sees a 50% loss on its crypto investment',
#    'description': 'El Salvador has snapped up 2,381 bitcoins since making it legal tender last year, but it has taken a significant loss, Bloomberg data shows.',
#    'url': 'https://markets.businessinsider.com/news/currencies/el-salvador-nayib-bukele-bitcoin-bond-50-percent-crypto-loss-2022-7',
#    'urlToImage': 'https://i.insider.com/62e2ac6ee1179200195ec0b1?width=1200&format=jpeg',
#    'publishedAt': '2022-07-28T15:58:55Z',
#    'content': 'Despite suffering heavy losses on its bitcoin bet, El Salvador still intends to issue bitcoin-backed bonds, the country\'s finance minister said.\r\n"We aren\'t going to have results overnight. We can\'t … [+1529 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Senate bill would hand bitcoin, ether oversight to commodities regulator - Reuters',
#    'description': 'A new bill introduced in the U.S. Senate would make the Commodity Futures Trading Commission (CFTC) the direct regulator of the biggest cryptocurrencies.',
#    'url': 'https://www.reuters.com/markets/us/senate-bill-would-hand-bitcoin-ether-oversight-commodities-regulator-2022-08-03/',
#    'urlToImage': 'https://www.reuters.com/resizer/D6UAwg9xkBVA9UviKEjSKPGTI3w=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/QQABWUBD6JJ3JJLRDJTC3IQMFI.jpg',
#    'publishedAt': '2022-08-03T15:16:00Z',
#    'content': 'WASHINGTON, Aug 3 (Reuters) - A new bill introduced in the U.S. Senate would make the Commodity Futures Trading Commission (CFTC) the direct regulator of the biggest cryptocurrencies.\r\nThe measure, i… [+2256 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Crypto lender Celsius gets court sign-off to sell bitcoin, but not stocks or debt - Reuters',
#    'description': 'Crypto lender Celsius Network LLC got signoff on Tuesday from a U.S. bankruptcy judge to mine and sell bitcoins during its bankruptcy.',
#    'url': 'https://www.reuters.com/legal/litigation/crypto-lender-celsius-gets-court-sign-off-sell-bitcoin-not-stocks-or-debt-2022-08-16/',
#    'urlToImage': 'https://www.reuters.com/resizer/M5_3h5HYQWktCbzkYCoKvSuEJBs=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/KK6EBWEIDBOHZJJDF3XGYIPGWY.jpg',
#    'publishedAt': '2022-08-16T22:51:00Z',
#    'content': '(Reuters) - Crypto lender Celsius Network LLC got signoff on Tuesday from a U.S. bankruptcy judge to mine and sell bitcoins during its bankruptcy.\r\nChief U.S. Bankruptcy Judge Martin Glenn in Manhatt… [+3139 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'bevans@insider.com (Brian Evans)',
#    'title': 'Tesla still has $222 million in digital assets on its balance sheet after dumping most of its bitcoin',
#    'description': 'In an SEC filing Monday, Tesla also disclosed a $170 million impairment charge on its crypto investments for the six-month period that ended June 30.',
#    'url': 'https://markets.businessinsider.com/news/currencies/tesla-crypto-holdings-222-billion-bitcoin-sale-elon-musk-sec-2022-7',
#    'urlToImage': 'https://i.insider.com/62ab2d108eacc300192df60b?width=1200&format=jpeg',
#    'publishedAt': '2022-07-25T14:10:01Z',
#    'content': 'Tesla still has $222 million on its balance sheet days after disclosing the sale of 75% of its bitcoin holdings, according to a new filing with the Securities and Exchange Commission.\xa0\r\nThe electric … [+1002 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Jea Yu',
#    'title': 'Financial services firm Block stock has fallen (-59%) in 2022',
#    'description': 'Financial services firm Block (NYSE: SQ) stock has fallen (-59%) into the toilet for 2022',
#    'url': 'https://www.entrepreneur.com/article/431585',
# ...
#    'description': 'Cryptoverse: What crisis? Venture capitalists bet big on crypto\xa0\xa0Reuters',
#    'url': 'https://www.reuters.com/technology/cryptoverse-what-crisis-venture-capitalists-bet-big-crypto-2022-07-26/',
#    'urlToImage': 'https://www.reuters.com/resizer/9BMltZgteA-YqoVeWpYwBtCntHE=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/6RYTBVRNWRN7FGDXL737UHXOOM.jpg',
#    'publishedAt': '2022-07-26T05:14:00Z',
#    'content': "July 26 (Reuters) - It's not all doom and gloom.\r\nEven as the crypto sector shivers in the bleak winter, venture capitalists are pouring money into digital currency and blockchain startups at a pace … [+3848 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Cryptoverse: What crisis? Venture capitalists bet big on crypto - Reuters.com',
#    'description': 'Cryptoverse: What crisis? Venture capitalists bet big on crypto\xa0\xa0Reuters.com',
#    'url': 'https://www.reuters.com/business/future-of-money/cryptoverse-what-crisis-venture-capitalists-bet-big-crypto-2022-07-26/',
#    'urlToImage': 'https://www.reuters.com/resizer/oGqBNBAiU3Jm9GGqQ02cMDdEnZc=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/LZQGHQAS4JJ75MW2MUFNUAL6DE.jpg',
#    'publishedAt': '2022-07-26T14:02:00Z',
#    'content': "July 26 (Reuters) - It's not all doom and gloom.\r\nEven as the crypto sector shivers in the bleak winter, venture capitalists are pouring money into digital currency and blockchain startups at a pace … [+3848 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'New guilty plea in BitMEX crypto exchange laundering case - Reuters',
#    'description': "The first employee of BitMEX pleaded guilty on Monday to violating U.S. bank secrecy laws by failing to establish an anti-money laundering program, following guilty pleas to the same charge by the cryptocurrency exchange's three co-founders.",
#    'url': 'https://www.reuters.com/technology/new-guilty-plea-bitmex-crypto-exchange-laundering-case-2022-08-08/',
#    'urlToImage': 'https://www.reuters.com/resizer/Wizo4hWPiYQhhHkKf1qY4bNcbS0=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/2UXLYI7K2NPYLCDOJL5NLIH2QU.jpg',
#    'publishedAt': '2022-08-08T21:33:00Z',
#    'content': 'NEW YORK, Aug 8 (Reuters) - The first employee of BitMEX pleaded guilty on Monday to violating U.S. bank secrecy laws by failing to establish an anti-money laundering program, following guilty pleas … [+1283 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Coinbase posts quarterly loss - Reuters.com',
#    'description': 'Coinbase Global Inc <a href="https://www.reuters.com/companies/COIN.O" target="_blank">(COIN.O)</a> reported a loss for the second quarter on Tuesday, hurt by a plunge in trading volumes as this year\'s rout in risky assets curbed investor appetite for trading…',
#    'url': 'https://www.reuters.com/technology/coinbase-posts-quarterly-loss-2022-08-09/',
#    'urlToImage': 'https://www.reuters.com/resizer/VFqQIm3yNO7V4K7If1sEOnR1sjU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/WITOR3WZZRNS3GRCTWKFF2XDAI.jpg',
#    'publishedAt': '2022-08-09T20:21:00Z',
#    'content': "Aug 9 (Reuters) - Coinbase Global Inc (COIN.O) reported a loss for the second quarter on Tuesday, hurt by a plunge in trading volumes as this year's rout in risky assets curbed investor appetite for … [+1099 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'EU securities watchdog to arm itself with crypto data - Reuters',
#    'description': 'The European Union\'s securities watchdog has begun preparations for increased scrutiny of crypto transactions after the bloc agreed groundbreaking rules to regulate what it called a "Wild West" sector, a public tender document showed.',
#    'url': 'https://www.reuters.com/technology/eu-securities-watchdog-arm-itself-with-crypto-data-2022-08-03/',
#    'urlToImage': 'https://www.reuters.com/resizer/yKlgZ4aCto6oSD9S-OC_2PvU_7c=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/WMD66GUZJ5N3XNYTHHJNLADPGM.jpg',
#    'publishedAt': '2022-08-03T08:30:00Z',
#    'content': "LONDON, Aug 3 (Reuters) - The European Union's securities watchdog has begun preparations for increased scrutiny of crypto transactions after the bloc agreed groundbreaking rules to regulate what it … [+1324 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Thai c.bank to test retail digital currency late this year - Reuters',
#    'description': "Thailand's central bank said on Friday it expected to test its retail digital currency from late this year to the middle of 2023, as an alternative payment option.",
#    'url': 'https://www.reuters.com/markets/currencies/thai-cbank-test-retail-digital-currency-late-this-year-2022-08-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/-NEiUWXMJ-fm3aORlo9G986-kUQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/MCHWHJZPJRMILGJ4B5SOEE3D3I.jpg',
#    'publishedAt': '2022-08-05T05:40:00Z',
#    'content': "BANGKOK, Aug 5(Reuters) - Thailand's central bank said on Friday it expected to test its retail digital currency from late this year to the middle of 2023, as an alternative payment option.\r\nDuring t… [+1078 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Abrdn buys stake in digital assets exchange Archax - Reuters',
#    'description': 'British asset manager abrdn <a href="https://www.reuters.com/companies/ABDN.L" target="_blank">(ABDN.L)</a> has bought a stake in digital assets exchange Archax, amid a wider push by investors into crypto-assets despite a recent plunge in value.',
#    'url': 'https://www.reuters.com/markets/europe/abrdn-buys-stake-digital-assets-exchange-archax-2022-08-12/',
#    'urlToImage': 'https://www.reuters.com/resizer/N0rhUs3arZyysc2nKvK3pt-nLJE=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/BI2HO5U3KZMKPFSW2XCORBT4AY.jpg',
#    'publishedAt': '2022-08-12T08:59:00Z',
#    'content': 'LONDON, Aug 12 (Reuters) - British asset manager abrdn (ABDN.L) has bought a stake in digital assets exchange Archax, amid a wider push by investors into crypto-assets despite a recent plunge in valu… [+1333 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'My Big Coin virtual currency firm founder convicted of fraud - Reuters.com',
#    'description': 'The founder of a defunct cryptocurrency business was convicted on Thursday of charges that he defrauded investors and customers out of millions of dollars through lies and false claims that its virtual currency My Big Coin was backed by $300 million in gold.',
#    'url': 'https://www.reuters.com/legal/government/my-big-coin-virtual-currency-firm-founder-convicted-fraud-2022-07-21/',
#    'urlToImage': 'https://www.reuters.com/resizer/F2EiOo0h_X-2JRibp-3NPTKXYGM=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/G5WNHRU3WNLK3DVGXKUTCIVE44.jpg',
#    'publishedAt': '2022-07-21T17:06:00Z',
#    'content': '(Reuters) - The founder of a defunct cryptocurrency business was convicted on Thursday of charges that he defrauded investors and customers out of millions of dollars through lies and false claims th… [+3024 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Losses from crypto hacks surged 60% to $1.9 bln in Jan-July -Chainalysis - Reuters',
#    'description': 'Losses arising from cryptocurrency hacks jumped nearly 60% in the first seven months of the year to $1.9 billion, propelled by a surge in funds stolen from decentralized finance (DeFi) protocols, according to a blog post from blockchain analysis firm Chainaly…',
#    'url': 'https://www.reuters.com/markets/us/losses-crypto-hacks-surged-60-19-bln-jan-july-chainalysis-2022-08-16/',
#    'urlToImage': 'https://www.reuters.com/resizer/ybcM0t3ZkbmcG5prhCuzON2vmgg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/GLY55FLNLBKZLNM7JXP3W4RIKA.jpg',
#    'publishedAt': '2022-08-16T11:38:00Z',
#    'content': 'NEW YORK, Aug 16 (Reuters) - Losses arising from cryptocurrency hacks jumped nearly 60% in the first seven months of the year to $1.9 billion, propelled by a surge in funds stolen from decentralized … [+2986 chars]'},
#   {'source': {'id': None, 'name': 'ReadWrite'},
#    'author': 'Shannon Flynn',
#    'title': 'Will the Crypto Market Reach Rock Bottom During Crypto Winter?',
#    'description': 'Cryptocurrency is seeing massive downturns that began after it peaked in November 2021.\xa0 According to Coinmarketcap, the total market cap lost two-thirds of its value, falling from $3 trillion to below $1 trillion on June 13. Bitcoin (BTC) suffered a loss of …',
#    'url': 'https://readwrite.com/will-the-crypto-market-reach-rock-bottom-during-crypto-winter/',
#    'urlToImage': 'https://images.readwrite.com/wp-content/uploads/2022/06/Crypto-Market-Reach.jpg',
#    'publishedAt': '2022-07-19T15:00:47Z',
#    'content': 'Cryptocurrency is seeing massive downturns that began after it peaked in November 2021.\xa0\r\nAccording to Coinmarketcap, the total market cap lost two-thirds of its value, falling from $3 trillion to be… [+6937 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'China vows privacy, information protection in using digital yuan - Reuters',
#    'description': 'China will fully respect privacy and protect personal information in using the digital yuan, state media quoted a senior central bank official as saying on Sunday, as Beijing encourages greater adoption of e-CNY.',
#    'url': 'https://www.reuters.com/world/china/china-vows-privacy-information-protection-using-digital-yuan-2022-07-25/',
#    'urlToImage': 'https://www.reuters.com/resizer/OcfdEuJmyyJCVOrik-vFRM7m67s=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/UMOWHMWLHZIAJFMCG6Z5G3YPN4.jpg',
#    'publishedAt': '2022-07-25T02:58:00Z',
#    'content': 'SHANGHAI, July 25 (Reuters) - China will fully respect privacy and protect personal information in using the digital yuan, state media quoted a senior central bank official as saying on Sunday, as Be… [+1782 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Mexican crypto exchange Bitso reaches more than 1 mln users in Brazil - Reuters',
#    'description': "Mexican cryptocurrency exchange Bitso has hit the one million users mark in Brazil about a year after it launched in the country, according to the company's Brazil chief.",
#    'url': 'https://www.reuters.com/technology/mexican-crypto-exchange-bitso-reaches-more-than-1-mln-users-brazil-2022-07-25/',
#    'urlToImage': 'https://www.reuters.com/resizer/8YB9Lg3JNaIabzyxhef0dPQHdE4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/437SX7JFUZLYRFAX32FFPGAUXQ.jpg',
#    'publishedAt': '2022-07-25T17:57:00Z',
#    'content': "SAO PAULO, July 25 (Reuters) - Mexican cryptocurrency exchange Bitso has hit the one million users mark in Brazil about a year after it launched in the country, according to the company's Brazil chie… [+1882 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Fraud charges in hacking case against Uber ex-security chief are dismissed - Reuters',
#    'description': 'A U.S. judge on Tuesday granted a request by prosecutors to dismiss fraud counts against a former Uber Technologies Inc <a href="https://www.reuters.com/companies/UBER.N" target="_blank">(UBER.N)</a> security chief also charged with covering up a 2016 data ha…',
#    'url': 'https://www.reuters.com/world/us/fraud-charges-hacking-case-against-uber-ex-security-chief-are-dismissed-2022-08-02/',
#    'urlToImage': 'https://www.reuters.com/resizer/grLTMfU2wwH4Gq9qvxK6m1r86eo=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/MBDIVXFECRON5LKOSWOIE4C5EY.jpg',
#    'publishedAt': '2022-08-02T23:53:00Z',
#    'content': 'Aug 2 (Reuters) - A U.S. judge on Tuesday granted a request by prosecutors to dismiss fraud counts against a former Uber Technologies Inc (UBER.N) security chief also charged with covering up a 2016 … [+1928 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Morning Bid: Fed doesn't see enough swallows for summer - Reuters",
#    'description': "Morning Bid: Fed doesn't see enough swallows for summer\xa0\xa0Reuters",
#    'url': 'https://www.reuters.com/markets/europe/fed-doesnt-see-enough-swallows-summer-2022-08-11/',
#    'urlToImage': 'https://www.reuters.com/resizer/GmFkUXqkFeK3azHG1GpOI0g69bY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/2WVPT67XRRMWZH2CDB7BFW2MRM.jpg',
#    'publishedAt': '2022-08-11T04:38:00Z',
#    'content': 'A look at the day ahead in markets from Alun John\r\nFed policymakers surged out of the traps last night, telling markets not to get too excited by the cooler-than-expected inflation reading, but to li… [+1888 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Peter Daisyme',
#    'title': 'Are We Headed for a Crypto Winter Recession?',
#    'description': 'Cryptocurrency professionals are beginning to issue warnings of a forthcoming &#8220;crypto winter,&#8221; in which interest in cryptocurrency significantly dies down. But are we truly headed for this eventuality? Or, are...',
#    'url': 'https://www.entrepreneur.com/article/432145',
#    'urlToImage': 'https://assets.entrepreneur.com/providers/due/hero-image-due-432145.jpeg',
#    'publishedAt': '2022-07-26T14:00:27Z',
#    'content': 'Cryptocurrency professionals are beginning to issue warnings of a forthcoming "crypto winter," in which interest in cryptocurrency significantly dies down. But are we truly headed for this eventualit… [+7407 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Babel Finance Lost Over $280 Million in Proprietary Trading With Customer Funds',
#    'description': 'Babel Finance, the troubled Asian crypto lender that abruptly halted client withdrawals last month, suffered heavy losses due to proprietary trading with customer funds, according to its restructuring proposal deck obtained by The Block. From a report: The de…',
#    'url': 'https://news.slashdot.org/story/22/07/29/1444220/babel-finance-lost-over-280-million-in-proprietary-trading-with-customer-funds',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/money_64.png',
#    'publishedAt': '2022-07-29T14:44:00Z',
#    'content': 'The deck, dated July 2022, reveals that Babel Finance lost more than $280 million in bitcoin (BTC) and ether (ETH) due to its proprietary trading failure. Specifically, it lost around 8,000 BTC and 5… [+1081 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': 'How One Company Survived a Ransomware Attack Without Paying the Ransom',
#    'description': 'Slashdot reader storagedude writes: The first signs of the ransomware attack at data storage vendor Spectra Logic were reports from a number of IT staffers about little things going wrong at the beginning of the day. Matters steadily worsened within a very sh…',
#    'url': 'https://it.slashdot.org/story/22/07/16/2357201/how-one-company-survived-a-ransomware-attack-without-paying-the-ransom',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/it_64.png',
#    'publishedAt': '2022-07-17T14:34:00Z',
#    'content': 'The first signs of the ransomware attack at data storage vendor Spectra Logic were reports from a number of IT staffers about little things going wrong at the beginning of the day. Matters steadily w… [+1256 chars]'}]}

# %%
# Print total articles
print(f"Total articles about Bitcoin: {bitcoin_articles['totalResults']}")

# Show sample article
bitcoin_articles["articles"][0]
# Out:
# Total articles about Bitcoin: 7331
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Gian M. Volpicelli',
#  'title': 'The Rise and Fall of a Bitcoin Mining Sensation',
#  'description': 'Compass Mining grew quickly during crypto’s halcyon days. Now, its customers and their thousands of mining machines are stuck.',
#  'url': 'https://www.wired.com/story/compass-mining-bitcoin-russia/',
#  'urlToImage': 'https://media.wired.com/photos/62e9c5e1d7368105da057de3/191:100/w_1280,c_limit/BitRiver-Mining-Center-Rise-And-Fall-Of-Bitcoin-Mining-Business-1184520941.jpg',
#  'publishedAt': '2022-08-03T11:00:00Z',
#  'content': "It was 8:45 in the morning of June 13 when Bill Stewart, the CEO of Maine-based bitcoin mining business Dynamics Mining, received a call from one of his employees. He's like, Every machine inside of … [+3472 chars]"}

# %%
# Fetch the Ethereum news articles
ether_articles = newsapi.get_everything(q="Ethereum", language="en", sort_by="relevancy")
ether_articles
# Out:
# {'status': 'ok',
#  'totalResults': 4630,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Kris Holt',
#    'title': 'Instagram is expanding NFT features to more than 100 countries',
#    'description': "The non-fungible token\r\n (NFT) market has fallen off a cliff\r\n, but that's not stopping Instagram from doubling down on digital collectibles. After a test launch in May\r\n, the app is expanding its NFT features to more than 100 countries across Africa, Asia-Pa…",
#    'url': 'https://www.engadget.com/instagram-nft-expansion-154058568.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-07/30e23da0-e979-11eb-bbaf-60938b4d69ff',
#    'publishedAt': '2022-08-04T15:40:58Z',
#    'content': "The non-fungible token\r\n (NFT) market has fallen off a cliff\r\n, but that's not stopping Instagram from doubling down on digital collectibles. After a test launch in May\r\n, the app is expanding its NF… [+1097 chars]"},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Kris Holt',
#    'title': "SEC charges 11 people over 'textbook' $300 million crypto Ponzi scheme",
#    'description': 'It\'s a day of the week ending in the letter "y," which inevitably means there\'s news of another\r\nmessy\r\nsaga\r\n in the cryptocurrency world. The Securities and Exchange Commission has charged 11 people who allegedly set up and promoted Forsage, which it said w…',
#    'url': 'https://www.engadget.com/sec-cryptocurrency-ponzi-scheme-forsage-175718451.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-07/9f595ce0-de17-11eb-bef2-e1b1456d84ae',
#    'publishedAt': '2022-08-02T17:57:18Z',
#    'content': 'It\'s a day of the week ending in the letter "y," which inevitably means there\'s news of another\r\nmessy\r\nsaga\r\n in the cryptocurrency world. The Securities and Exchange Commission has charged 11 peopl… [+1855 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Igor Bonifacic',
#    'title': 'GameStop is letting someone sell an NFT that references a 9/11 photo',
#    'description': 'Less than two weeks into its soft launch, GameStop’s NFT marketplace is already courting controversy. Among the NFTs listed on the platform is an artwork called “Falling Man” that was spotted by \r\nWeb3 is Going Great\r\n. There’s no mistaking it, the NFT refere…',
#    'url': 'https://www.engadget.com/gamestop-falling-man-nft-181910264.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2022-07/33de5a60-0ab2-11ed-af5f-1167c8493d13',
#    'publishedAt': '2022-07-23T18:19:10Z',
#    'content': 'Less than two weeks into its soft launch, GameStops NFT marketplace is already courting controversy. Among the NFTs listed on the platform is an artwork called Falling Man that was spotted by \r\nWeb3 … [+1429 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Daniel Van Boom',
#    'title': 'Ethereum Merge Explained: Why It Matters For Everyone - CNET',
#    'description': 'Ethereum will soon adopt a proof-of-stake system, which some say will reduce its carbon emissions by over 99%.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/ethereum-merge-explained-why-it-matters-for-everyone/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/e20cf953a1e584b3e9442bad7df0fd8dcd60d147/2022/07/14/70fe602c-0eca-4060-9e47-2375450b2ad9/gettyimages-1241390930.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-07-25T04:06:00Z',
#    'content': 'The Ethereum Merge is significant, and not just for people who own crypto. In the works in one form or another since 2014, the long-delayed Merge will see the second biggest blockchain reduce its car… [+10658 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Ethereum Software Update Planned for September After Successful Test',
#    'description': 'The most ambitious upgrade to the Ethereum blockchain should take place in September, possibly closer to the middle of the month, developers working on the project said during a conference call after what was billed as a final dress rehearsal. From a report: …',
#    'url': 'https://tech.slashdot.org/story/22/08/11/1645242/ethereum-software-update-planned-for-september-after-successful-test',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/network_64.png',
#    'publishedAt': '2022-08-11T16:44:00Z',
#    'content': 'Developers have picked a number of so-called total terminal difficulty required of the final block mined in Ethereum before the network switches to new software. Figuring out the exact date range whe… [+1084 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'bevans@insider.com (Brian Evans)',
#    'title': "Vitalik Buterin says the ethereum network's upcoming 'surge' will boost the network's scalability",
#    'description': '"At the end of this road map, ethereum will be able to process 100,000 transactions per second," Buterin told a conference in Paris on Thursday.',
#    'url': 'https://markets.businessinsider.com/news/currencies/vitalik-buterin-ethereum-network-merge-surge-ether-scalability-crypto-news-2022-7',
#    'urlToImage': 'https://i.insider.com/62d979ec0c98f500195ed9ca?width=1200&format=jpeg',
#    'publishedAt': '2022-07-21T16:32:48Z',
#    'content': 'Ethereum will improve upon its scalability after the completion of the so-called surge, co-founder Vitalik Buterin said Thursday.\xa0\r\nAt the Ethereum Community Conference in Paris, he addressed overall… [+1344 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Crypto platform Zipmex to start releasing Bitcoin, Ether for customers - Reuters',
#    'description': 'Crypto exchange Zipmex will release Ethereum and Bitcoin tokens from this week, a spokesperson said on Monday, allowing 60% of its customers to retrieve their digital assets after a suspension of withdrawals from its Z Wallet product.',
#    'url': 'https://www.reuters.com/technology/crypto-platform-zipmex-start-releasing-bitcoin-ether-customers-2022-08-08/',
#    'urlToImage': 'https://www.reuters.com/resizer/Fd5a-BznMketgq1x6iGznPIbLTM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/DAQG47AXNNNY5CJY7EM4QCRX6Q.jpg',
#    'publishedAt': '2022-08-08T10:29:00Z',
#    'content': 'BANGKOK, Aug 8 (Reuters) - Crypto exchange Zipmex will release Ethereum and Bitcoin tokens from this week, a spokesperson said on Monday, allowing 60% of its customers to retrieve their digital asset… [+874 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Barr',
#    'title': 'SEC Says 11 People Fooled Users Out of $300 Million in Crypto Pyramid Scheme',
#    'description': 'Some crypto critics like Vivaldi CEO Jon von Tetzchner have called the entire apparatus of crypto “nothing more than a pyramid scheme.” It’s an easy claim when you cite the ever-growing number of scams in the crypto scene that have cost users over $1 billion\xa0…',
#    'url': 'https://gizmodo.com/crypto-pyramid-scheme-sec-forsage-1849357134',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/9d8f609ac017a5e63fc751514d8d9dca.jpg',
#    'publishedAt': '2022-08-01T21:35:00Z',
#    'content': 'Some crypto critics like Vivaldi CEO Jon von Tetzchner have called the entire apparatus of crypto nothing more than a pyramid scheme. Its an easy claim when you cite the ever-growing number of scams … [+3393 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Daniel Van Boom',
#    'title': 'Ethereum Shows Signs of Life, Hits $1,400 After Merge News - CNET',
#    'description': 'As of last week, Ether had lost nearly 70% of its value since the year began.',
#    'url': 'https://www.cnet.com/personal-finance/ethereum-shows-signs-of-life-hits-1400-after-merge-news/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/7d959cc901d7ae496b56a9f12708b28f454bf991/2022/07/18/8cbad42e-b6d8-40f5-b16c-7dbf448f9779/gettyimages-1237113120.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-07-18T03:35:08Z',
#    'content': "It's a way off the $4,800 all-time-high, but the ether cryptocurrency is showing signs of life after a long downward spiral that began in April. Following news that the long-awaited Ethereum Merge co… [+1616 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': "Ether has rallied 50% over the last month, blowing past bitcoin's gains, ahead of 'merge' for Ethereum 2.0",
#    'description': 'Bitcoin — the biggest cryptocurrency by market cap — is up about 16.6% from a month ago, trading around $23,296 on Friday.',
#    'url': 'https://markets.businessinsider.com/news/currencies/ethereum-price-today-eth-beats-btc-up-50-percent-merge-2022-7',
#    'urlToImage': 'https://i.insider.com/62dace98d001100019100561?width=1200&format=jpeg',
#    'publishedAt': '2022-07-22T16:40:44Z',
#    'content': 'Over the last month, ether has significantly outperformed bitcoin as enthusiasm grows ahead of the highly anticipated "merge" event for Ethereum 2.0.\r\nThe second-largest cryptocurrency was hovering a… [+1359 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': 'North Korea has laundered $1 billion in crypto via Tornado Cash - and the US Treasury just slammed the platform with sanctions',
#    'description': 'Ethereum-based crypto mixer Tornado Cash has been used by North Korea to launder $1 billion in crypto, according to TRM Labs.',
#    'url': 'https://markets.businessinsider.com/news/currencies/north-korea-launder-treasury-ethereum-us-billion-sanctions-tornado-cash-2022-8',
#    'urlToImage': 'https://i.insider.com/62f140f6254496001960f5bd?width=1200&format=jpeg',
#    'publishedAt': '2022-08-08T18:38:43Z',
#    'content': "The US Treasury Department's Office of Foreign Asset Control on Monday sanctioned crypto platform Tornado Cash, which North Korean hackers have used for laundering.\xa0\r\nThe sanctions prohibit any Ameri… [+2121 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': "Crypto markets have 'found a floor' as anticipation builds that Ethereum merge is viable in 2022, JPMorgan says",
#    'description': 'The merge is designed to transfer the Ethereum blockchain away from a proof-of-work network and instead to a proof-of-stake system.',
#    'url': 'https://markets.businessinsider.com/news/currencies/crypto-markets-found-a-floor-jpmorgan-ethereum-merge-viable-2022-2022-8',
#    'urlToImage': 'https://i.insider.com/628e13817be71f001936f9e7?width=1200&format=jpeg',
#    'publishedAt': '2022-08-08T19:45:39Z',
#    'content': 'After bitcoin fell as much as 75% from its peak, crypto markets appear to have "found a floor," JPMorgan said in a note on Monday.\xa0\r\nBitcoin and ether have surged 36% and 102% from their mid-June low… [+1887 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Amit Katwala',
#    'title': 'NFTs Are Conquering Soccer',
#    'description': 'And not in a good way.',
#    'url': 'https://www.wired.com/story/nfts-conquering-soccer/',
#    'urlToImage': 'https://media.wired.com/photos/62edac72807038f14f5e911e/191:100/w_1280,c_limit/NFTs-Conquering-Soccer-Culture-1391755248.jpg',
#    'publishedAt': '2022-08-06T11:00:00Z',
#    'content': 'When he speaks to clubs across Europe who want to launch NFTs, their primary concern is money. The number one thing is, Oh, we want to make millions of pounds overnight, Mangnall says. Theres a real … [+3005 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'As Crypto Crashed, Coinbase Stopped Some Notifications',
#    'description': 'An anonymous reader shares a report:Back in November 2021, cryptocurrencies, which saw a huge surge during most of the pandemic, suddenly began to nosedive. Joe Hovde, a New York-based data scientist, decided that this might be his moment to buy into crypto: …',
#    'url': 'https://slashdot.org/story/22/08/15/1539221/as-crypto-crashed-coinbase-stopped-some-notifications',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/business_64.png',
#    'publishedAt': '2022-08-15T16:41:00Z',
#    'content': 'Back in November 2021, cryptocurrencies, which saw a huge surge during most of the pandemic, suddenly began to nosedive. Joe Hovde, a New York-based data scientist, decided that this might be his mom… [+1641 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin rises 3.4% to $24584; up 39.7% from year low in June - Reuters',
#    'description': 'Bitcoin rose 3.36% to $24,584.24 at 1707 GMT on Saturday, adding $798.93 to its previous close.',
#    'url': 'https://www.reuters.com/technology/bitcoin-rises-34-24584-up-397-year-low-june-2022-07-30/',
#    'urlToImage': 'https://www.reuters.com/resizer/olDHRm0jmk0gc_1U1JwzC8ItOzY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/KGBQSYSMQRO47BZLCENBDEJYZA.jpg',
#    'publishedAt': '2022-07-30T17:21:00Z',
#    'content': "July 30 (Reuters) - Bitcoin rose 3.36% to $24,584.24 at 1707 GMT on Saturday, adding $798.93 to its previous close.\r\nBitcoin, the world's biggest, best-known cryptocurrency, is up 39.7% from the year… [+345 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin rises 6.9% to $22717 - Reuters',
#    'description': 'Bitcoin rose 6.85% to $22,717.05 at 22:05 GMT on Wednesday, adding $1,457.27 to its previous close.',
#    'url': 'https://www.reuters.com/technology/bitcoin-rises-69-22717-2022-07-27/',
#    'urlToImage': 'https://www.reuters.com/resizer/eeQb8FK8oNm7KlzdFaYT9lvuJ5s=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/LP3EEKNH25PZXG4NK2TOEKO2VY.jpg',
#    'publishedAt': '2022-07-27T22:15:00Z',
#    'content': "July 27 (Reuters) - Bitcoin rose 6.85% to $22,717.05 at 22:05 GMT on Wednesday, adding $1,457.27 to its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is up 29.1% from t… [+352 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'Traders expect the ether rally to fizzle out as upcoming merge to proof-of-stake system will be a ‘sell the news’ event',
#    'description': 'The large buy side demand for ether call options that expire in September has led to a "state of extreme bullish bias," Glassnode said.',
#    'url': 'https://markets.businessinsider.com/news/currencies/ethereum-merge-sell-the-news-event-ether-prices-to-fizzle-2022-8',
#    'urlToImage': 'https://i.insider.com/612f973512b9cc001963a752?width=1200&format=jpeg',
#    'publishedAt': '2022-08-12T15:05:55Z',
#    'content': 'The highly anticipated Ethereum Merge that is expected next month could ultimately prove to be a "sell the news" event for ether prices, according to Glassnode.\r\nThe Ethereum blockchain is expected t… [+2277 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Crypto derivatives volumes surge to $3.12 trillion in July - CryptoCompare - Reuters',
#    'description': 'Cryptocurrency derivatives trading on centralised exchanges rose to $3.12 trillion in July, a 13% monthly increase, researcher CryptoCompare said on Thursday, as crypto prices show signs of recovery from the recent market crash.',
#    'url': 'https://www.reuters.com/technology/crypto-derivatives-volumes-surge-312-trillion-july-cryptocompare-2022-08-11/',
#    'urlToImage': 'https://www.reuters.com/resizer/xTN_w6bEGIrdArCCNImqU8X1WnY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/VEMNAX3DIBMGZGCA5HIDFVEFVM.jpg',
#    'publishedAt': '2022-08-11T16:13:00Z',
#    'content': 'LONDON, Aug 11 (Reuters) - Cryptocurrency derivatives trading on centralised exchanges rose to $3.12 trillion in July, a 13% monthly increase, researcher CryptoCompare said on Thursday, as crypto pri… [+2234 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'Solana DeFi Protocol Nirvana Drained of Liquidity After Flash Loan Exploit',
#    'description': "Nirvana Finance, a Solana-based yield protocol, suffered a $3.5 million exploit utilizing flash loans to manipulate and drain its liquidity pools, blockchain data shows. CoinDesk reports: The price of the protocol's native ANA token fell over 80% in the past …",
#    'url': 'https://slashdot.org/story/22/07/28/2046222/solana-defi-protocol-nirvana-drained-of-liquidity-after-flash-loan-exploit',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2022-07-28T23:20:00Z',
#    'content': "The price of the protocol's native ANA token fell over 80% in the past few hours, while its NIRV stablecoin lost its peg to the U.S. dollar and dropped to 8 cents at writing time, CoinGecko data show… [+1513 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'jsor@insider.com (Jennifer Sor)',
#    'title': "Bitcoin bull Mike Novogratz says crypto's forced deleveraging is over and bitcoin is still an asset to hold amid economic uncertainty",
#    'description': '"The worst is over. There is no more forced deleveraging that\'s going to happen," the famed crypto investor told CNBC.',
#    'url': 'https://markets.businessinsider.com/news/currencies/bitcoin-mike-novogratz-crypto-outlook-crash-deleveraging-cycle-ethereum-merge-2022-8',
#    'urlToImage': 'https://i.insider.com/62f111c28677d80018ee50fd?width=1200&format=jpeg',
#    'publishedAt': '2022-08-10T16:46:31Z',
#    'content': 'Billionaire bitcoin bull Mike Novogratz believes the forced deleveraging of the cryptocurrency market is over and that investors can expect new narratives to shape the space following a brutal quarte… [+1750 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Lauren Goode',
#    'title': 'No One Cares About My Framed NFT Art',
#    'description': 'Some NFTs are frame-worthy, just like any other photo. What you’re actually framing is still a mystery.',
#    'url': 'https://www.wired.com/story/no-one-cares-about-my-framed-nft-art/',
#    'urlToImage': 'https://media.wired.com/photos/62e9863a73e44c149d0e800f/191:100/w_1280,c_limit/NFT-Frames-Gear-GettyImages-1387322248.jpg',
#    'publishedAt': '2022-08-03T11:00:00Z',
#    'content': 'Stephen Curry wiggles his shoulders on my kitchen counter. No one cares, not even the most devout Curry fans. Occasionally a friend asks what it is, this never-ending loop of Curry successfully launc… [+4435 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'ztayeb@businessinsider.com (Zahra Tayeb)',
#    'title': "Anthony Scaramucci's SkyBridge has halted withdrawals from one of its funds as the stock market deteriorates",
#    'description': 'SkyBridge Capital froze withdrawals from its Legion Strategy fund, which has 20% of its assets in private companies, which are harder to sell.',
#    'url': 'https://markets.businessinsider.com/news/currencies/anthony-scaramucci-skybridge-capital-suspends-withdrawals-fund-2022-7',
#    'urlToImage': 'https://i.insider.com/62d6837fbc4c770018b759e1?width=1200&format=jpeg',
#    'publishedAt': '2022-07-19T10:40:45Z',
#    'content': "Anthony Scaramucci's SkyBridge Capital has suspended client withdrawals from one of its funds against a backdrop of a depreciating stock market, according to Bloomberg.\r\nThe Legion Strategies fund st… [+2214 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Emily Rella',
#    'title': "$200 Million Was Stolen in One of the 'Most Chaotic Hacks' the Crypto World Has Seen",
#    'description': 'Crypto platform Nomad suffered a massive breach on Monday.',
#    'url': 'https://www.entrepreneur.com/article/432558',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1659451791-GettyImages-870113288.jpg',
#    'publishedAt': '2022-08-02T14:41:00Z',
#    'content': 'Another massive hack has shaken the crypto world amid what\'s been dubbed the season of the "crypto winter."\r\nAn estimated $200 million was stolen from crypto startup Nomad, a platform that allows use… [+2143 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Coinbase ex-manager pleads not guilty to insider trading charges - Reuters',
#    'description': 'Ishan Wahi, a former product manager at Coinbase Global Inc <a href="https://www.reuters.com/companies/COIN.O" target="_blank">(COIN.O)</a>, pleaded not guilty on Wednesday to wire fraud charges in what U.S. prosecutors called the first insider trading case i…',
#    'url': 'https://www.reuters.com/technology/coinbase-ex-manager-pleads-not-guilty-insider-trading-charges-2022-08-03/',
#    'urlToImage': 'https://www.reuters.com/resizer/XsA-mJuk-UfiaqX_lbwtVZ8Egp4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/TK5SKXCQMNPBFOQOZZTJB55GHQ.jpg',
#    'publishedAt': '2022-08-03T17:16:00Z',
#    'content': 'NEW YORK, Aug 3 (Reuters) - Ishan Wahi, a former product manager at Coinbase Global Inc (COIN.O), pleaded not guilty on Wednesday to wire fraud charges in what U.S. prosecutors called the first insid… [+1193 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Adi Robertson',
#    'title': 'The Dune bible crypto collective wants to sell its Dune bible',
#    'description': 'Spice DAO, a cryptocurrency decentralized autonomous organization (or DAO) built around a script bible for Alejandro Jodorowsky’s never-made adaptation of Frank Herbert’s Dune, is planning a radical shift in direction.',
#    'url': 'https://www.theverge.com/2022/7/27/23280490/spice-dao-jodorowsky-dune-bible-crypto-sale-planned-liquidation',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/5jIINdPeHGYeRydaWDJo5nWfsQk=/0x116:1066x674/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23175021/FJKO3wxXoAMGhVE.jpeg',
#    'publishedAt': '2022-07-27T16:58:17Z',
#    'content': 'Also, its no longer a collective\r\nImage: Spice DAO\r\nThe cryptocurrency collective built around a copy of Alejandro Jodorowskys Dune script bible will no longer be a collective and is trying to sell i… [+4094 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Corinne Reichert',
#    'title': 'US Treasury Bars Americans From Using Tornado Cash Crypto Mixer - CNET',
#    'description': 'The virtual cash mixer has been used to launder more than $7 billion since 2019, Treasury says.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/us-treasury-bars-americans-from-using-tornado-cash-crypto-mixer/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/ab186e80a239811b248dd8c8064ee7bed70f1a8a/2022/08/08/3cd24907-480f-4243-8f84-ccab47ddbd15/gettyimages-1369189803-1.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-08-08T22:00:38Z',
#    'content': 'The US Treasury has sanctioned virtual currency mixer Tornado Cash, it said Monday, labelling the service "a threat to US national security."\r\nTornado Cash operates on the Ethereum blockchain and obs… [+1073 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Daniel Van Boom',
#    'title': 'How An NFT Trader Lost $150K Trying to Troll Twitter Bots - CNET',
#    'description': 'A Bored Ape Yacht Club whale tried to have fun trolling Twitter bots but ended up self inflicting a 100-ether wound on himself.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/how-an-nft-trader-lost-150k-trying-to-troll-twitter-bots/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/8a0b6e35fd585e499308be8776c80a1f73c41137/2022/07/21/443d5da6-4de0-4642-bf96-5fc36fb93a5c/c129bbfda68e8da2b1452ce3a06943c8.png?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-07-21T01:49:00Z',
#    'content': 'Scams and frauds are ubiquitous in crypto, but sometimes the biggest losses are those people inflict upon themselves. On Wednesday, one NFT trader suffered a spectacular loss of 100 ether, or $150,00… [+2966 chars]'},
#   {'source': {'id': None, 'name': 'Cryptowiky.com'},
#    'author': 'https://www.facebook.com/cryptowikyofficial/',
#    'title': 'Ethereum merge on schedule after successful Goerli test merge',
#    'description': "There is growing confidence that the Ethereum Merge, scheduled for mid-September, won't be postponed after the Goerli merge went smoothly.",
#    'url': 'https://cryptowiky.com/ethereum-merge-on-schedule-after-successful-goerli-test-merge/',
#    'urlToImage': 'https://i0.wp.com/cryptowiky.com/wp-content/uploads/2022/08/Untitled-design8-1.png',
#    'publishedAt': '2022-08-11T17:49:44Z',
#    'content': 'There is growing confidence that the Ethereum Merge, scheduled for mid-September, won’t be postponed after the Goerli merge went smoothly.\r\nAfter Ropsten and Sepolia, Goerli was the final testnet lef… [+2411 chars]'},
#   {'source': {'id': None, 'name': 'Digital Trends'},
#    'author': 'Zak Islam',
#    'title': 'Intel’s latest GPUs are bad news for crypto miners',
#    'description': 'The drivers for Intel’s Arc Alchemist GPUs seemingly do not support the ability to mine crypto currency in any capacity, particularly for Ethereum.',
#    'url': 'https://www.digitaltrends.com/computing/intels-latest-gpus-are-bad-news-for-crypto-miners/',
#    'urlToImage': 'https://www.digitaltrends.com/wp-content/uploads/2022/04/intel-arc-alchemist-gpu-01.jpg?p=1',
#    'publishedAt': '2022-07-21T14:05:06Z',
#    'content': 'The drivers for Intels Arc Alchemist GPUs seemingly do not support the ability to mine crypto currency.\r\nAs reported by Toms Hardware, anyone who equips their system with Intel’s Arc A380 board for d… [+2332 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': "As Metaverse Land Prices Plummet, Mark Cuban Says Buying Digital Land Is 'the Dumbest Sh*t Ever'",
#    'description': 'Mark Cuban, the billionaire Dallas Mavericks owner and avid crypto enthusiast, is not sold on the metaverse. "The worst part is that people are buying real estate in these places. That\'s just the dumbest shit ever," he told the crypto-themed YouTube channel A…',
#    'url': 'https://tech.slashdot.org/story/22/08/10/1629230/as-metaverse-land-prices-plummet-mark-cuban-says-buying-digital-land-is-the-dumbest-sht-ever',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/technology_64.png',
#    'publishedAt': '2022-08-10T16:40:00Z',
#    'content': "Cuban's comments come as the hype surrounding the metaverse -- a term that loosely describes an emerging virtual world where people can hang out, play, and shop -- seems to be cooling. Last November,… [+1258 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Damon Nam',
#    'title': "The Beginner's Guide to Investing in Cryptocurrencies",
#    'description': 'In this article, we review what are cryptocurrencies and how you can personally invest in them.',
#    'url': 'https://www.entrepreneur.com/article/430705',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1658869884-GettyImages-1335900085.jpg',
#    'publishedAt': '2022-08-01T19:00:00Z',
#    'content': 'Recent years have seen a plethora of cryptocurrencies being launched, starting with Bitcoin during the Great Financial Crisis in 2008. Today, the total market capitalization of these cryptocurrencies… [+5302 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'stabahriti@insider.com (Sam Tabahriti)',
#    'title': "GameStop's NFT marketplace appears to remove an image that referenced a defining moment of the 9/11 attacks",
#    'description': 'GameStop appears to have taken down the NFT called "Falling Man", which looked similar to the image of a person falling from the World Trade Center.',
#    'url': 'https://www.businessinsider.com/gamestop-appears-remove-nft-referencing-9-11-attacks-2022-7',
#    'urlToImage': 'https://i.insider.com/62dd557f21142200185eec35?width=1200&format=jpeg',
#    'publishedAt': '2022-07-24T14:36:04Z',
#    'content': 'GameStop\'s non-fungible token marketplace appears to have removed an image referencing a defining moment of the 9/11 attacks.\r\nWeb3 is going great spotted the NFT called "Falling Man", which depicts … [+1650 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'bevans@insider.com (Brian Evans)',
#    'title': 'US stocks extend rally as a drop in wholesale prices boosts optimism that inflation is cooling',
#    'description': 'The producer price index fell 0.5% from June to July, the first month-over-month decrease since April 2020.',
#    'url': 'https://markets.businessinsider.com/news/stocks/stock-market-news-today-wholesale-prices-energy-gas-inflation-recession-2022-8',
#    'urlToImage': 'https://i.insider.com/61e87ee59386c900185f6969?width=1200&format=jpeg',
#    'publishedAt': '2022-08-11T13:42:33Z',
#    'content': 'US stocks continued to rally Thursday as wholesale price data gave traders fresh confidence that inflation could finally be easing.\xa0\r\nThe producer price index fell 0.5% from June to July, the first m… [+1773 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'jsor@insider.com (Jennifer Sor)',
#    'title': 'Dutch police arrested a suspected developer of the US-sanctioned Tornado Cash crypto mixer and are looking into potentially more arrests',
#    'description': 'A Tornado Cash developer has been arrested for of helping money launderers on the crypto-mixing platform, and police say more arrests are possible.',
#    'url': 'https://markets.businessinsider.com/news/currencies/tornado-cash-crypto-mixer-developer-suspect-money-laundering-north-korea-2022-8',
#    'urlToImage': 'https://i.insider.com/606c2afca7d803001963ee59?width=1200&format=jpeg',
#    'publishedAt': '2022-08-12T15:54:08Z',
#    'content': 'The Netherlands Crime Agency (FIOD) said it arrested a 29-year-old who is a suspected developer of Tornado Cash, the crypto mixer that was slapped with US sanctions earlier this week.\r\nThe platform, … [+1494 chars]'},
#   {'source': {'id': None, 'name': 'VentureBeat'},
#    'author': 'Dean Takahashi',
#    'title': 'Jules Miller: How 150 VCs created the VC3 DAO for decentralized investing',
#    'description': 'The VC3 DAO is an interesting move to get VCs to collaborate on decentralized investing and show support for the Web3 movement.',
#    'url': 'https://venturebeat.com/2022/08/01/jules-miller-how-150-vcs-created-the-vc3-dao-for-decentralized-investing/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2022/08/vc3-investors.jpg?w=1200&strip=all',
#    'publishedAt': '2022-08-01T14:30:00Z',
#    'content': 'Venture capitalists often seek tech startups that promise disruption, but its not every day that you see VCs try to disrupt their own way of doing things.\r\nThats why the VC3 DAO is an interesting mov… [+1061 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Daniel Van Boom',
#    'title': 'Ethereum Rallies Past $1,600 Despite 40-Year Inflation High - CNET',
#    'description': "Ether is up 40% over the past week after news broke that Ethereum's move to proof of stake is tentatively slated for September 19.",
#    'url': 'https://www.cnet.com/personal-finance/ethereum-rallies-past-1600-despite-40-year-inflation-high/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/7d959cc901d7ae496b56a9f12708b28f454bf991/2022/07/18/8cbad42e-b6d8-40f5-b16c-7dbf448f9779/gettyimages-1237113120.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-07-19T00:18:00Z',
#    'content': "It's not a new all-time high, but any good news is something to covet in crypto winter. Ether, the second biggest cryptocurrency by market cap, is up around 40% in the past seven days, exceeding $1,6… [+2463 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': 'How Wall Street bulls are reacting to fresh inflation data — and what you want to know about a potential rally.',
#    'description': "A top JPMorgan strategist broke down why he's adopted a bullish outlook after last week's data — and experts share top stock picks for recessions.",
#    'url': 'https://www.businessinsider.com/wall-street-bulls-inflation-rally-stock-market-economy-fundstrat-jpmorgan-2022-8',
#    'urlToImage': 'https://i.insider.com/62e79984c1c56b0018b49259?width=1200&format=jpeg',
#    'publishedAt': '2022-08-14T23:00:00Z',
#    'content': "Welcome back team. I'm your host, Phil Rosen, back in Manhattan after some weeks on the west coast.\xa0\r\nToday, it's as oppressive as a sauna with no exit, but I missed it all the same. (I can't get eno… [+4882 chars]"},
#   {'source': {'id': None, 'name': 'MakeUseOf'},
#    'author': 'Katie Rees',
#    'title': 'The Quick Guide to Mining Vertcoin',
#    'description': "It's easier to mine than Bitcoin or Ethereum, so why not give it a try?",
#    'url': 'https://www.makeuseof.com/quick-guide-mining-vertcoin/',
#    'urlToImage': 'https://static1.makeuseofimages.com/wordpress/wp-content/uploads/2022/07/gpu-vertcoin-1.jpg',
#    'publishedAt': '2022-07-19T15:30:15Z',
#    'content': "While you may think mining the most valuable cryptos is the best option, it isn't always the case. Today, mining smaller, less well-known coins can still make you a healthy profit without incurring h… [+6730 chars]"},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern',
#    'title': 'Meta’s BlenderBot 3 wants to chat – but can you trust it?',
#    'description': 'Facebook’s parent company has created a bot capable of weighing in on almost any topic – from radicalisation to sending Mark Zuckerberg to jailLast week, researchers at Facebook’s parent company Meta released BlenderBot 3, a “publicly available chatbot that i…',
#    'url': 'https://amp.theguardian.com/technology/2022/aug/10/meta-ai-facebook-blenderbot-3-chatbot',
#    'urlToImage': 'https://i.guim.co.uk/img/media/fce93079d42c7cc6d23e56bb1cd54e626f1d7a5d/66_0_1200_720/master/1200.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=3773bc02a7897acda7095c9bdc4871e5',
#    'publishedAt': '2022-08-10T10:31:39Z',
#    'content': 'Last week, researchers at Facebooks parent company Meta released BlenderBot 3, a publicly available chatbot that improves its skills and safety over time. The chatbot is built on top of Metas OPT-175… [+9884 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': "Here's what's in store for the stock market for the rest of this summer and beyond",
#    'description': 'The biggest story in markets today is how stocks will navigate the bear market this summer. Two experts from top firms break down opposite forecasts.',
#    'url': 'https://www.businessinsider.com/heres-how-the-stock-market-could-tumble-or-rally-this-summer-2022-7',
#    'urlToImage': 'https://i.insider.com/62bef25a9b16eb0018020bff?width=1200&format=jpeg',
#    'publishedAt': '2022-07-19T10:50:00Z',
#    'content': "Happy July 19, readers. Phil Rosen here, coming to you from NYC. On this date in 1969, Neil Armstrong and Buzz Aldrin went into orbit around the moon.\xa0\r\nIt's been five decades since astronauts walked… [+5175 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'prosen@insider.com (Phil Rosen)',
#    'title': "Here's why inflation may have peaked — but a recession could still loom",
#    'description': 'The biggest story in markets today is that a top economist said inflation may have peaked, but a downturn still looms. Plus, Wall Street stock picks.',
#    'url': 'https://www.businessinsider.com/inflation-peak-economy-recession-markets-mohamed-el-erian-stocks-2022-7',
#    'urlToImage': 'https://i.insider.com/6270066486fa90001905ff5d?width=1200&format=jpeg',
#    'publishedAt': '2022-07-25T10:45:00Z',
#    'content': 'I hope this newsletter finds you well, even as inflation runs amok and everything from groceries to gas is more expensive than a year ago. Phil Rosen here, coming to you from Los Angeles today.\r\nNo m… [+4618 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'A rally in bitcoin and ether push crypto market cap back above $1 trillion as digital assets struggle against bear market',
#    'description': 'Investor sentiment often follows price, so if the rally in bitcoin and ether can hold, it should lure more investors back into the crypto space.',
#    'url': 'https://markets.businessinsider.com/news/currencies/crypto-market-bitcoin-ether-rally-market-value-1-trillion-coinbase-2022-7',
#    'urlToImage': 'https://i.insider.com/62d58c07aac2aa0018cb9d57?width=1200&format=jpeg',
#    'publishedAt': '2022-07-18T17:34:05Z',
#    'content': "A big rally in both bitcoin and ether on Monday helped drive the cryptocurrency market value back above the $1 trillion threshold for the first time since June 13.\r\nMonday's gains should be a welcome… [+1982 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Carla Mozée)',
#    'title': 'SEC charges 11 people for running a crypto Ponzi scheme that raised $300 million from retail investors worldwide',
#    'description': 'A defendant known as Lola Ferrari was among those who created Forsage, a website used to bilk millions of dollars from crypto investors, the SEC said.',
#    'url': 'https://markets.businessinsider.com/news/currencies/crypto-scam-sec-ponzi-scheme-forsage-fraud-ethereum-lola-ferrari-2022-8',
#    'urlToImage': 'https://i.insider.com/612f799b9ef1e50018f91d2d?width=1200&format=jpeg',
#    'publishedAt': '2022-08-01T19:22:03Z',
#    'content': 'The Securities and Exchange Commission on Monday charged 11 people for operating a crypto scheme that allowed them to raise more than $300 million from millions of retail investors worldwide.\xa0\r\nThe s… [+2605 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'jsor@insider.com (Jennifer Sor)',
#    'title': "The total value of the crypto market has surged in recent weeks as bears start to buy back in and bulls 'hold on for dear life'",
#    'description': 'Bank of America analysts said investors appear to be coming off the sidelines and back into crypto, but a recession would likely spark another sell-off.',
#    'url': 'https://markets.businessinsider.com/news/currencies/crypto-market-value-crash-contagion-recovery-bear-market-bofa-bitcoin-2022-8',
#    'urlToImage': 'https://i.insider.com/62e7e759c1c56b0018b49b83?width=1200&format=jpeg',
#    'publishedAt': '2022-08-01T16:38:08Z',
#    'content': 'The total value of the cryptocurrency market has surged in recent weeks, with Bank of America analysts stating that it may be a sign that bears are beginning to buy back in as bulls continue to "hold… [+2029 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Katie Canales)',
#    'title': "Mark Cuban says buying virtual real estate is 'the dumbest s--- ever' as metaverse hype appears to be fading",
#    'description': '"The worst part is that people are buying real estate in these places," billionaire investor Mark Cuban told the YouTube channel Altcoin Daily.',
#    'url': 'https://www.businessinsider.com/mark-cuban-buying-metaverse-land-dumbest-shit-ever-2022-8',
#    'urlToImage': 'https://i.insider.com/62f269dfcc15bf00182f8dbb?width=1200&format=jpeg',
#    'publishedAt': '2022-08-09T15:46:56Z',
#    'content': 'Billionaire investor Mark Cuban is out on digital land purchases.\r\nThe "Shark Tank" star spoke to the crypto YouTube channel Altcoin Daily on Sunday about a range of topics, including the feasibility… [+2404 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Katie Canales)',
#    'title': 'An NFT power player, who owns a whopping 57 Bored Apes, says he accidentally lost $150,000 on a joke auction bid',
#    'description': 'The investor created an NFT as a joke and bid 100 ETH on it. He accepted a $2,900 offer for the gag — before the buyer turned around and sold it back.',
#    'url': 'https://www.businessinsider.com/bored-ape-nft-owner-lost-150000-joke-bid-2022-7',
#    'urlToImage': 'https://i.insider.com/62d97746d0011000190fcea5?width=1200&format=jpeg',
#    'publishedAt': '2022-07-21T18:27:35Z',
#    'content': 'A big-time NFT investor who owns 57 digital art pieces from the Bored Ape Yacht Club said he lost $150,000 via a joke bid.\r\nInvestor Franklin Caldwell, whose Twitter handle is @franklinisbored, said … [+2228 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur Store',
#    'title': 'Why Every Entrepreneur Should Learn to Code',
#    'description': "Learning to code is essential in today's workplace.",
#    'url': 'https://www.entrepreneur.com/article/433270',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1660244884-Ent-LearnToCod.jpeg',
#    'publishedAt': '2022-08-13T15:30:00Z',
#    'content': 'The business world is constantly changing and, as an entrepreneur, you need to be ready to change with it. That means staying on top of new technologies and trends and taking time to learn the things… [+1825 chars]'},
#   {'source': {'id': None, 'name': 'BuzzFeed News'},
#    'author': 'Katie Notopoulos',
#    'title': "Crypto Diaries: A Crypto Entrepreneur Whose Wife Doesn't Allow Bitcoin Talk",
#    'description': 'Kyle Hill is the latest in our series on what people in crypto actually do all day.View Entire Post ›',
#    'url': 'https://www.buzzfeednews.com/article/katienotopoulos/crypto-diaries-kyle-hill-bitcoin',
#    'urlToImage': 'https://img.buzzfeed.com/buzzfeed-static/static/2022-08/5/19/enhanced/469e12dce80b/original-6277-1659728244-42.jpg?crop=1444:756;0,486%26downsize=1250:*',
#    'publishedAt': '2022-08-08T14:37:46Z',
#    'content': '7 p.m. Soccer night. I drive to the field in Santa Monica. I snap a picture with my Stacks water bottle and tag @nftsonbitcoin on IG. I post two quick memes to my story the first one comparing fiat c… [+1764 chars]'},
#   {'source': {'id': None, 'name': 'Fiod.nl'},
#    'author': 'Wietske Visser',
#    'title': 'Arrest of suspected developer of Tornado Cash',
#    'description': 'On Wednesday 10 August, the FIOD arrested a 29-year-old man in Amsterdam. He is suspected of involvement in concealing criminal financial flows and facilitating money laundering through the mixing of cryptocurrencies through the decentralised Ethereum mixing …',
#    'url': 'https://www.fiod.nl/arrest-of-suspected-developer-of-tornado-cash/',
#    'urlToImage': 'https://www.fiod.nl/wp-content/uploads/2021/12/Koolmees.jpg',
#    'publishedAt': '2022-08-12T10:05:40Z',
#    'content': 'Tornado Cash is a mixing service for cryptocurrencies. The online service makes it possible to conceal the origin or destination of cryptocurrencies. The (criminal) origin of the cryptocurrencies is … [+1593 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Simon Chandler)',
#    'title': 'How to invest in blockchain, the high-risk but high-potential technology behind bitcoin and other digital transactions',
#    'description': 'Investing in blockchain technology has become hot due to its role in bitcoin and other promising developments for its use. Here are ways to invest.',
#    'url': 'https://www.businessinsider.com/personal-finance/how-to-invest-in-blockchain-technology',
#    'urlToImage': 'https://i.insider.com/5ff4f229d184b30018aad332?width=1200&format=jpeg',
#    'publishedAt': '2022-07-29T20:26:39Z',
#    'content': 'Bitcoin often dominates the financial news, riveting investors with its volatile price swings and appreciation potential. Getting far less attention, though, is blockchain, the database technology on… [+10653 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Losses from crypto hacks surged 60% to $1.9 bln in Jan-July -Chainalysis - Reuters',
#    'description': 'Losses arising from cryptocurrency hacks jumped nearly 60% in the first seven months of the year to $1.9 billion, propelled by a surge in funds stolen from decentralized finance (DeFi) protocols, according to a blog post from blockchain analysis firm Chainaly…',
#    'url': 'https://www.reuters.com/markets/us/losses-crypto-hacks-surged-60-19-bln-jan-july-chainalysis-2022-08-16/',
#    'urlToImage': 'https://www.reuters.com/resizer/ybcM0t3ZkbmcG5prhCuzON2vmgg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/GLY55FLNLBKZLNM7JXP3W4RIKA.jpg',
#    'publishedAt': '2022-08-16T11:38:00Z',
#    'content': 'NEW YORK, Aug 16 (Reuters) - Losses arising from cryptocurrency hacks jumped nearly 60% in the first seven months of the year to $1.9 billion, propelled by a surge in funds stolen from decentralized … [+2986 chars]'},
#   {'source': {'id': None, 'name': 'Threadreaderapp.com'},
#    'author': None,
#    'title': 'Nomad drained of $150m due to a coding mistake',
#    'description': '@samczsun: 1/ Nomad just got drained for over $150M in one of the most chaotic hacks that Web3 has ever seen. How exactly did this happen, and what was the root cause? Allow me to take you...',
#    'url': 'https://threadreaderapp.com/thread/1554252024723546112.html',
#    'urlToImage': 'https://threadreaderapp.com/images/screenshots/thread/1554252024723546112.jpg',
#    'publishedAt': '2022-08-02T14:25:53Z',
#    'content': 'Support us! We are indie developers!\r\nThis site is made by just two indie developers on a laptop doing marketing, support and development! Read more about the story.\r\nBecome a Premium Member ($3/mont… [+395 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'gglover@insider.com (George Glover)',
#    'title': "Global stocks mixed as cautious investors wait for key US inflation data and more earnings after Nvidia's miss",
#    'description': 'If CPI data due Wednesday fails to show a drop in headline inflation, it could take the wind out of stocks and set the tone for the summer, an analyst said.',
#    'url': 'https://markets.businessinsider.com/news/stocks/stock-market-news-inflation-investing-analysis-q2-earnings-coinbase-roblox-2022-8',
#    'urlToImage': 'https://i.insider.com/62f21e07cc15bf00182f8473?width=1200&format=jpeg',
#    'publishedAt': '2022-08-09T09:55:08Z',
#    'content': 'US futures rose slightly in subdued trading Tuesday, but stocks in Europe and Asia were mixed as investors counted down to a key US inflation reading, with the earnings season entering its home stret… [+2579 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Joshua H. Davidson',
#    'title': "If You Have No Clue What Web3 Is, You're Not Alone. Here's a Breakdown of the Future of the Internet.",
#    'description': "Hype or not, Web3 is on the horizon, and it's critical for entrepreneurs and small business owners to know what to be on the lookout for.",
#    'url': 'https://www.entrepreneur.com/article/431223',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1659476740-GettyImages-1368757787.jpg',
#    'publishedAt': '2022-08-05T16:00:00Z',
#    'content': "You almost can't escape the buzz surrounding NFTs, cryptocurrency and Web3. Some say these technologies will come to revolutionize every aspect of society. Others say this is a pipe dream.\r\nAs the ma… [+7073 chars]"},
#   {'source': {'id': None, 'name': 'Small Business Trends'},
#    'author': 'Samson Haileyesus',
#    'title': 'What is Cardano?',
# ...
#    'publishedAt': '2022-07-26T19:00:00Z',
#    'content': 'As of November last year, there were over 26,000 fintech startups globally, up from over 12,000 in 2019. This figure is expected to rise further, thanks to the increasing adoption of fintech services… [+6086 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Travis Hoium)',
#    'title': 'Why Bitcoin, Ethereum, and Coinbase Jumped Today',
#    'description': 'Coinbase made some very bullish statements today.',
#    'url': 'https://www.fool.com/investing/2022/07/20/why-bitcoin-ethereum-and-coinbase-jumped-today/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/691070/bitcoin-falling-apart.jpg',
#    'publishedAt': '2022-07-20T17:44:18Z',
#    'content': 'What happened\xa0\r\nThe crypto rally continues to have legs and it helps that investors are pouring back into risk assets again. It certainly helps that the Nasdaq Composite is up 1.9% in early afternoon… [+2542 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Travis Hoium)',
#    'title': 'Why Ethereum Pulled Crypto Higher Today',
#    'description': '"The Merge" may already be helping crypto values.',
#    'url': 'https://www.fool.com/investing/2022/07/16/why-ethereum-solana-and-arweave-jumped-on-saturday/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/690512/cryptocurrency-image.jpg',
#    'publishedAt': '2022-07-16T20:51:00Z',
#    'content': 'What happened\xa0\r\nSaturday has been a wild day of trading in the crypto market and the day is only a little over half over. At about 11:45 a.m. ET Ethereum(ETH 6.17%) quickly jumped about 10% and those… [+2380 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Travis Hoium)',
#    'title': 'Why Ethereum, Coinbase, and Bitcoin Popped Today',
#    'description': "Coinbase's SEC battle and Ethereum's Merge are in focus today.",
#    'url': 'https://www.fool.com/investing/2022/07/27/why-ethereum-coinbase-and-bitcoin-popped-today/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/692317/crypto-market.jpg',
#    'publishedAt': '2022-07-27T17:24:51Z',
#    'content': "What happened\xa0\r\nUp and down. Down and up. Cryptocurrencies can't seem to find a direction this week and the movement depends on the day. Today, the move is positive and there was some relatively good… [+2484 chars]"},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Travis Hoium)',
#    'title': 'Why Bitcoin, Ethereum, and Polkadot Jumped Today',
#    'description': 'Crypto markets are shrugging off higher interest rates and slowing GDP in the U.S.',
#    'url': 'https://www.fool.com/investing/2022/07/28/why-bitcoin-ethereum-and-polkadot-jumped-today/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/692600/rocket-chart-money.jpg',
#    'publishedAt': '2022-07-28T15:01:22Z',
#    'content': "What happened\xa0\r\nSecond-quarter 2022 gross domestic product (GDP) was down 0.9% from a year ago, showing the U.S. is technically in a recession, but you wouldn't know it from the market's reaction tod… [+2546 chars]"},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (RJ Fulton)',
#    'title': 'Why Ethereum Looks Better Than Ever',
#    'description': 'The highly anticipated platform update might have an end in sight.',
#    'url': 'https://www.fool.com/investing/2022/07/28/why-ethereum-looks-better-than-ever/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/691850/ethereum-chart.jpg',
#    'publishedAt': '2022-07-28T12:31:00Z',
#    'content': 'The Ethereum\xa0(ETH 9.92%) blockchain is closer to migrating to a proof-of-stake consensus mechanism than ever before. Since its creation, the smart contract-enabled blockchain ran on a proof-of-work m… [+3464 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Adria Cimino)',
#    'title': '2 Cryptos That Could Outpace Ethereum',
#    'description': 'Now may be a good time to get in on these young crypto players.',
#    'url': 'https://www.fool.com/investing/2022/07/23/2-cryptos-that-could-outpace-ethereum/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/691240/gettyimages-1320686310.jpg',
#    'publishedAt': '2022-07-23T10:00:00Z',
#    'content': "Ethereum(ETH -4.14%) is the world's second-biggest cryptocurrency by market value -- and on its way to changing the way business is done. That's because decentralized applications (dApps) on the bloc… [+3686 chars]"},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Travis Hoium)',
#    'title': 'Why Coinbase, Ethereum, and Dogecoin Popped Today',
#    'description': 'Coinbase continues to lead the crypto market higher.',
#    'url': 'https://www.fool.com/investing/2022/08/05/why-coinbase-ethereum-and-dogecoin-popped-today/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/694639/crypto-and-nfts.jpg',
#    'publishedAt': '2022-08-05T19:48:36Z',
#    'content': "What happened\xa0\r\nWall Street's trading week is ending positively for cryptocurrencies as most major tokens rise sharply on Friday. Even exchange Coinbase Global\xa0(COIN 4.67%) has continued its meteoric… [+2354 chars]"},
#   {'source': {'id': 'bloomberg', 'name': 'Bloomberg'},
#    'author': 'Olga Kharif',
#    'title': 'Crypto Miner Pushback Suggests Ethereum Offshoots Are Coming',
#    'description': 'A monkey wrench is about to be thrown into the already complicated transition that the Ethereum blockchain is slated to go through soon.',
#    'url': 'https://www.bloomberg.com/news/articles/2022-08-06/crypto-miner-pushback-suggests-ethereum-offshoots-are-coming',
#    'urlToImage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/i8PqihIiJ6Ng/v0/1200x800.jpg',
#    'publishedAt': '2022-08-06T14:18:16Z',
#    'content': 'A monkey wrench is about to be thrown into the already complicated transition that the Ethereum blockchain is slated to go through soon.\r\nIn as early as September, Ethereum is expected to undergo a m… [+4593 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Katie Brockman)',
#    'title': 'Ethereum in 3 Figures: Is It a Buy?',
#    'description': 'Ethereum has been surging. Is now the time to invest?',
#    'url': 'https://www.fool.com/investing/2022/08/13/ethereum-in-3-figures-is-it-a-buy/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/695917/ethereum-tokens.jpg',
#    'publishedAt': '2022-08-13T10:15:00Z',
#    'content': "Ethereum(ETH 6.33%) has had a strong couple of months, as its price continues to rebound amid this crypto winter. If you've been on the fence about investing in cryptocurrency, now may seem like a pr… [+3252 chars]"},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Katie Brockman)',
#    'title': 'Is Now the Time to Invest in Ethereum?',
#    'description': 'Ethereum seems to be bouncing back. Should you buy now?',
#    'url': 'https://www.fool.com/investing/2022/07/23/is-now-the-time-to-invest-in-ethereum/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/691383/person-looking-at-a-laptop-looking-focused.jpg',
#    'publishedAt': '2022-07-23T09:30:00Z',
#    'content': 'The price of Ethereum(ETH -4.45%) has been soaring lately, up more than 49% over the last three weeks.\r\nThis surge is at least partly due to developers setting a tentative date of Sept. 19 for the re… [+3088 chars]'},
#   {'source': {'id': None, 'name': 'Awwwards.com'},
#    'author': None,
#    'title': 'Bao Society',
#    'description': 'Bao is a collection of 3,888 randomly generated 3D model artworks generated on the Ethereum Blockchain.',
#    'url': 'https://www.awwwards.com/sites/bao-society',
#    'urlToImage': 'https://assets.awwwards.com/awards/sites_of_the_day/2022/08/bao-interior-1.jpg',
#    'publishedAt': '2022-08-15T00:00:00Z',
#    'content': 'Jury vote eliminated\r\nSites are sent to a minimum of 18 Design Jury members, the 3 scores furthest from the average will be automatically eliminated by our system. SOTD will then be sent to the Devel… [+81 chars]'},
#   {'source': {'id': None, 'name': 'Substack.com'},
#    'author': 'Jay Pinho',
#    'title': 'The endless search for a crypto use case',
#    'description': 'Are we there yet?',
#    'url': 'https://networked.substack.com/p/the-endless-search-for-a-crypto-use',
#    'urlToImage': 'https://substackcdn.com/image/fetch/w_1200,h_600,c_limit,f_jpg,q_auto:good,fl_progressive:steep/https%3A%2F%2Fpbs.substack.com%2Fmedia%2FFKFvQQHWYAEarpj.jpg',
#    'publishedAt': '2022-08-02T16:03:51Z',
#    'content': 'Today I read a Nat Eliason post titled Does Crypto Have Any Good Use Cases?1\r\nI dont want to pick on Nat. In fact, I have called his prior crypto writing essential reading, precisely because he has b… [+23784 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Jon Quast)',
#    'title': 'Ethereum Classic Soars Over 70% This Week, and This Other Cryptocurrency Is Close Behind',
#    'description': 'Unlike Ethereum Classic, Bitcoin Gold might not have a fundamental driver to explain its move up.',
#    'url': 'https://www.fool.com/investing/2022/07/22/ethereum-classic-soars-over-70-this-week-and-this/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/691567/surprise-investor-news-coffee.jpg',
#    'publishedAt': '2022-07-22T19:21:28Z',
#    'content': "What happened\r\nCryptocurrency\xa0Ethereum Classic(ETC -0.88%) is having a week to write home about. According to CoinMarketCap, Ethereum Classic is up 72% over the past seven days, and it's likely becau… [+2140 chars]"},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Chris MacDonald)',
#    'title': 'Why the Ethereum Merge Is Prompting More Incredible Surges in These 3 Tokens',
#    'description': 'The upcoming Ethereum merge could be a bigger catalyst for these three tokens.',
#    'url': 'https://www.fool.com/investing/2022/07/28/why-the-ethereum-merge-ethereum-classic-lido-stake/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/692680/eth.jpg',
#    'publishedAt': '2022-07-28T18:30:07Z',
#    'content': 'What happened\r\nIn the latest bullish turn in the crypto market, most major cryptocurrencies are catching a bid once again today. However, despite an impressive 10.7% increase in the overall crypto ma… [+3316 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Katie Brockman)',
#    'title': 'Is Now Really the Time to Invest in Ethereum?',
#    'description': 'Ethereum has been surging lately, but is it safe to invest right now?',
#    'url': 'https://www.fool.com/investing/2022/08/04/is-now-really-the-time-to-invest-in-ethereum/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/693730/person-sitting-on-the-floor-looking-at-a-laptop.jpg',
#    'publishedAt': '2022-08-04T11:00:00Z',
#    'content': "After a long crypto winter, the price of Ethereum(ETH -2.83%) has been increasing in recent weeks. In fact, over the past month alone, it's up nearly 55%.\r\nThis surge is partly due to developers sett… [+3651 chars]"},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (RJ Fulton)',
#    'title': 'Why Now Is a Good Time to Buy Ethereum',
#    'description': 'Ethereum is up nearly 50% this month -- but it has even more upside.',
#    'url': 'https://www.fool.com/investing/2022/08/09/why-now-is-a-good-time-to-buy-ethereum/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/694666/ethereum-chart.jpg',
#    'publishedAt': '2022-08-09T10:00:00Z',
#    'content': "Over the last few weeks, hope that Ethereum's (ETH -1.79%) move to a proof-of-stake consensus mechanism is coming sooner than later helped the broader crypto market thaw from a recent freeze. Known a… [+3647 chars]"},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (RJ Fulton)',
#    'title': "Buy the Rumor, Sell the News: Why Ethereum's Merge Presents a Buying Opportunity",
#    'description': 'Ethereum has nearly doubled in two months, but it has plenty more room to run.',
#    'url': 'https://www.fool.com/investing/2022/08/16/buy-the-rumor-sell-the-news-why-ethereums-merge-pr/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/695941/ethereum-chart.jpg',
#    'publishedAt': '2022-08-16T10:00:00Z',
#    'content': 'One of the most important events in crypto history looks to be all but set in stone. Ethereum (ETH -0.77%)\xa0developers successfully merged the Goerli testnet, the third and final testnet to be rehears… [+4210 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Dominic Basulto)',
#    'title': 'Missed Out On Ethereum? Buy This Cryptocurrency Now',
#    'description': 'Solana could offer greater upside potential than Ethereum at a much more attractive entry price.',
#    'url': 'https://www.fool.com/investing/2022/08/03/missed-out-on-ethereum-buy-this-cryptocurrency-now/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/692613/woman-financial-planning-budget.jpg',
#    'publishedAt': '2022-08-03T11:15:00Z',
#    'content': 'This summer, Ethereum(ETH 4.76%) is arguably the most exciting cryptocurrency in the world. And for good reason -- its upcoming Merge has enormous implications, not just for the future price of Ether… [+4485 chars]'},
#   {'source': {'id': None, 'name': 'Matt-rickard.com'},
#    'author': 'Matt Rickard',
#    'title': 'Sybil Attacks on Airdrops',
#    'description': 'Sybil attacks occur when networked systems get gamed by a small number of accounts, creating multiple identities.\n\nProof-of-stake and Proof-of-work mechanisms on blockchains provide Sybil resistance against attacks. These mechanisms prevent a single user from…',
#    'url': 'https://matt-rickard.com/sybil-attacks-on-airdrops/',
#    'urlToImage': None,
#    'publishedAt': '2022-07-17T17:23:56Z',
#    'content': 'Sybil attacks occur when networked systems get gamed by a small number of accounts, creating multiple identities. \r\nProof-of-stake and Proof-of-work mechanisms on blockchains provide Sybil resistance… [+2481 chars]'},
#   {'source': {'id': None, 'name': 'Quartz India'},
#    'author': 'Nicolás Rivero',
#    'title': 'The rapid growth of crypto mining is threatening to slow the US clean energy transition',
#    'description': 'Bitcoin and ethereum mining are growing quickly in the US after China cracked down on cryptocurrencies. But energy-intensive mining rigs are already using as much electricity as all Houston homes.',
#    'url': 'https://qz.com/2190137/crypto-mining-threatens-to-slow-the-us-clean-energy-transition/',
#    'urlToImage': 'https://cms.qz.com/wp-content/uploads/2022/07/2022-06-28T121617Z_464414466_RC2Z0V9V8R7C_RTRMADP_3_RUSSIA-CRYPTO-CURRENCY-REGULATOR-e1658258780205.jpg?quality=75&strip=all&w=1200&h=630&crop=1',
#    'publishedAt': '2022-07-20T09:00:53Z',
#    'content': 'Six of the biggest US crypto mining companies already use as much electricity as all the homes in the city of Houston. Over the next three years, these companies plan to triple their electricity cons… [+4163 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Dominic Basulto)',
#    'title': "Missed Out on Ethereum? Here's What to Buy Now",
#    'description': "It's still possible to get in early on Avalanche, which has proven to be a worthy competitor to Ethereum.",
#    'url': 'https://www.fool.com/investing/2022/08/09/missed-out-on-ethereum-heres-what-to-buy-now/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/694674/smiling-couple-celebrates-good-news-on-the-computer.jpg',
#    'publishedAt': '2022-08-09T10:30:00Z',
#    'content': 'If you bought Ethereum(ETH -3.05%) back in July 2015 when it first launched, you would now be up a whopping 47,000%, making it one of the greatest crypto investment plays ever. Unfortunately, it may … [+4074 chars]'}]}

# %%
# Print total articles
print(f"Total articles about Bitcoin: {ether_articles['totalResults']}")

# Show sample article
ether_articles["articles"][0]
# Out:
# Total articles about Bitcoin: 4630
# {'source': {'id': 'engadget', 'name': 'Engadget'},
#  'author': 'Kris Holt',
#  'title': 'Instagram is expanding NFT features to more than 100 countries',
#  'description': "The non-fungible token\r\n (NFT) market has fallen off a cliff\r\n, but that's not stopping Instagram from doubling down on digital collectibles. After a test launch in May\r\n, the app is expanding its NFT features to more than 100 countries across Africa, Asia-Pa…",
#  'url': 'https://www.engadget.com/instagram-nft-expansion-154058568.html',
#  'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-07/30e23da0-e979-11eb-bbaf-60938b4d69ff',
#  'publishedAt': '2022-08-04T15:40:58Z',
#  'content': "The non-fungible token\r\n (NFT) market has fallen off a cliff\r\n, but that's not stopping Instagram from doubling down on digital collectibles. After a test launch in May\r\n, the app is expanding its NF… [+1097 chars]"}

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-08-03  It was 8:45 in the morning of June 13 when Bil...    0.5574
# 1  2022-08-02  Tools to trace cryptocurrencies have, over jus...    0.0000
# 2  2022-07-25  You gotta hand it to some people for being imp...    0.5994
# 3  2022-07-16  People in Russia will soon no longer be allowe...    0.0516
# 4  2022-07-21  Elon Musk-owned electric vehicle making compan...    0.2023
#
#    positive  negative  neutral
# 0     0.119     0.000    0.881
# 1     0.000     0.000    1.000
# 2     0.130     0.034    0.835
# 3     0.088     0.057    0.855
# 4     0.053     0.000    0.947

# %%
# Create the Ethereum sentiment scores DataFrame
ether_sentiments = []

for article in ether_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ether_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ether_df = pd.DataFrame(ether_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ether_df = ether_df[cols]

ether_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-08-04  The non-fungible token\r\n (NFT) market has fa...   -0.0217
# 1  2022-08-02  It's a day of the week ending in the letter "y...   -0.2732
# 2  2022-07-23  Less than two weeks into its soft launch, Game...   -0.1531
# 3  2022-07-25  The Ethereum Merge is significant, and not jus...    0.2023
# 4  2022-08-11  Developers have picked a number of so-called t...   -0.6124
#
#    positive  negative  neutral
# 0     0.048     0.051    0.901
# 1     0.059     0.115    0.827
# 2     0.000     0.045    0.955
# 3     0.048     0.000    0.952
# 4     0.036     0.145    0.820

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#          compound    positive   negative     neutral
# count  100.000000  100.000000  100.00000  100.000000
# mean     0.047334    0.067400    0.05378    0.878780
# std      0.461507    0.071537    0.07226    0.088582
# min     -0.908100    0.000000    0.00000    0.628000
# 25%     -0.318200    0.000000    0.00000    0.826000
# 50%      0.000000    0.059000    0.00000    0.873500
# 75%      0.378825    0.115750    0.10625    0.945500
# max      0.924600    0.372000    0.30700    1.000000

# %%
# Describe the Ethereum Sentiment
ether_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.147180    0.072620    0.039460    0.887910
# std      0.435177    0.072231    0.063144    0.087492
# min     -0.936600    0.000000    0.000000    0.646000
# 25%     -0.022725    0.000000    0.000000    0.824250
# 50%      0.051350    0.061000    0.000000    0.895500
# 75%      0.514625    0.121750    0.057000    0.952750
# max      0.921600    0.299000    0.354000    1.000000

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
nltk.download('stopwords')

sw = set(stopwords.words('english'))



# Expand the default stopwords list if necessary
sw_addon = {'the'}
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\saif_\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    sw_addon = {'the'}
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase
    # Remove the stop words
    tokens = [word.lower() for word in lem if word.lower() not in sw.union(sw_addon)]
    
    return tokens

# %%
# Create a new tokens column for Bitcoin
bitcoin_df['tokens'] = bitcoin_df['text'].apply(tokenizer)

bitcoin_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-08-03  It was 8:45 in the morning of June 13 when Bil...    0.5574
# 1  2022-08-02  Tools to trace cryptocurrencies have, over jus...    0.0000
# 2  2022-07-25  You gotta hand it to some people for being imp...    0.5994
# 3  2022-07-16  People in Russia will soon no longer be allowe...    0.0516
# 4  2022-07-21  Elon Musk-owned electric vehicle making compan...    0.2023
#
#    positive  negative  neutral  \
# 0     0.119     0.000    0.881
# 1     0.000     0.000    1.000
# 2     0.130     0.034    0.835
# 3     0.088     0.057    0.855
# 4     0.053     0.000    0.947
#
#                                               tokens
# 0  [wa, morning, june, bill, stewart, ceo, maineb...
# 1  [tools, trace, cryptocurrencies, last, several...
# 2  [got, ta, hand, people, impetuous, even, face,...
# 3  [people, russia, soon, longer, allowed, use, d...
# 4  [elon, muskowned, electric, vehicle, making, c...

# %%
# Create a new tokens column for Ethereum
ether_df['tokens'] = ether_df['text'].apply(tokenizer)

ether_df.head()
# Out:
#          date                                               text  compound  \
# 0  2022-08-04  The non-fungible token\r\n (NFT) market has fa...   -0.0217
# 1  2022-08-02  It's a day of the week ending in the letter "y...   -0.2732
# 2  2022-07-23  Less than two weeks into its soft launch, Game...   -0.1531
# 3  2022-07-25  The Ethereum Merge is significant, and not jus...    0.2023
# 4  2022-08-11  Developers have picked a number of so-called t...   -0.6124
#
#    positive  negative  neutral  \
# 0     0.048     0.051    0.901
# 1     0.059     0.115    0.827
# 2     0.000     0.045    0.955
# 3     0.048     0.000    0.952
# 4     0.036     0.145    0.820
#
#                                               tokens
# 0  [nonfungible, token, nft, market, ha, fallen, ...
# 1  [day, week, ending, letter, inevitably, mean, ...
# 2  [less, two, week, soft, launch, gamestops, nft...
# 3  [ethereum, merge, significant, people, crypto,...
# 4  [developers, picked, number, socalled, total, ...

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2

big_string_1 = bitcoin_df['text'].str.cat()
processed_1 = tokenizer(big_string_1)
bigrams_1 = Counter(ngrams(processed_1, n=2))

# %%
# Generate the Ethereum N-grams where N=2
big_string_2 = ether_df['text'].str.cat()
processed_2 = tokenizer(big_string_2)
bigrams_2 = Counter(ngrams(processed_2, n=2))

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
top_10_btc = token_count(bigrams_1, 10)

top_10_btc
# Out:
# [(('aug', 'reuters'), 8),
#  (('charsjuly', 'reuters'), 7),
#  (('hard', 'drive'), 6),
#  (('digital', 'asset'), 6),
#  (('charsaug', 'reuters'), 6),
#  (('july', 'reuters'), 6),
#  (('bitcoin', 'holding'), 5),
#  (('world', 'biggest'), 4),
#  (('second', 'quarter'), 4),
#  (('asset', 'manager'), 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
top_10_eth = token_count(bigrams_2, 10)

top_10_eth
# Out:
# [(('cryptocurrency', 'market'), 6),
#  (('ethereum', 'merge'), 4),
#  (('aug', 'reuters'), 4),
#  (('crypto', 'market'), 4),
#  (('securities', 'exchange'), 3),
#  (('exchange', 'commission'), 3),
#  (('nft', 'marketplace'), 3),
#  (('called', 'falling'), 3),
#  (('falling', 'man'), 3),
#  (('tornado', 'cash'), 3)]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\saif_\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Generate the Bitcoin word cloud
wc_btc = WordCloud().generate(big_string_1)
plt.imshow(wc_btc)

# %%
# Generate the Ethereum word cloud
wc_eth = WordCloud().generate(big_string_2)
plt.imshow(wc_eth)

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

print("finished download of package")
# Out:
# finished download of package

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %%
# Concatenate all of the Bitcoin text together
bitcoin_text = (big_string_1)

# %%
# Run the NER processor on all of the text
doc_1 = nlp(bitcoin_text)

# Add a title to the document
doc_1.user_data["NER Visualization - Bitcoin"] = "NER Visualization - Bitcoin"

# %%
# Render the visualization
displacy.render(doc_1, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">It was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8:45 in the morning of June 13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  when
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bill Stewart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the CEO of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -based bitcoin mining business
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dynamics Mining
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , received a call from one of his employees. He's like, Every machine inside of … [+3472 chars]Tools to trace cryptocurrencies have, over just
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last several years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , allowed law enforcement agencies to convict dark web black market administrators, recover
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in ransomware payments, seiz… [+3510 chars]You gotta hand it to some people for being impetuous even in the face of extraordinary odds. Imagine looking for a single hard drive amidst a literal heap of trash. Well, thats been one
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  goal … [+4091 chars]People in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will soon no longer be allowed to use digital assets as a form of payment.
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  president
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vladimir Putin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has signed a bill into law prohibiting the use of digital assets, such as … [+1436 chars]Elon
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# -owned electric vehicle making company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has sold a significant amount of its
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  holdings, the firm said in a statement. Reporting its earnings for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Q2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>From Bitcoin highs to blockchain bridge lows, to why some of the worlds biggest technology companies are freezing jobs, we round up
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  big stories in the world of virtual money.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Krist
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+17 chars]July 27 (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Bitcoin rose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6.85%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22,717.05
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22:05
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GMT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line

# %%
# List all Entities
for ent in doc_1.ents:
    print(ent.text)
# Out:
# 8:45 in the morning of June 13
# Bill Stewart
# Maine
# Dynamics Mining
# the last several years
# millions
# UK
# mans
# Russia
# Russian
# Vladimir Putin
# Musk
# Tesla
# Bitcoin
# Q2
# the weeks
# Krist
# Reuters
# 6.85%
# 22,717.05
# 22:05
# GMT
# Wednesday
# 1,457.27
# 29.1%
# 2021
# Tesla
# $936 million
# the second quarter of 2022
# Bitcoin
# 75
# 24,000
# first
# August
# US
# this week
# as much as 4%
# 24,191
# 2
# Reuters
# a good month
# months
# more than 17%
# July
# October
# chars]July 30
# Reuters
# 3.36%
# 24,584.24
# GMT
# Saturday
# 798.93
# 39.7%
# the year
# 2022
# Wednesday
# $2.3 billion
# second-quarter
# a record $3.3 billion
# first
# 11
# Reuters
# the United States
# chars]July 19
# Reuters
# months
# chars]NEW YORK
# July 20
# Reuters
# Wednesday
# Tesla Inc
# TSLA.O
# about 75%
# fiat
# ten
# Wednesday
# approximately 75%
# Democrats
# the Environmental Protection Agency
# Department of Energy
# US
# chars]July 29
# Reuters
# Bitcoin Valley
# Honduran
# Santa Lucia
# one
# Today
# +8199 chars]El Salvador
# Tuesday
# $1.6 billion
# Central America
# la
# Michael Saylor
# quarterly
# more than $900 million
# the last month
# Ethereum 2.0
# second
# 21 million
# 19 million
# just two million
# first
# CNN Business' Before
# Bell
# This week
# The U.S. Department of Justice
# Celsius Networks'
# Jack Dorsey
# Twitter
# the Tysons Corner
# Virginia
# 1989
# Bitcoin
# MicroStrategy
# Phong Le
# July 21
# Reuters
# Brazilian
# Mercado Bitcoin
# Mexican
# the end of the year
# Latin Amer
# chars]NEW YORK
# July 19
# Reuters
# Texas
# 8
# Reuters
# Ethereum and Bitcoin
# this week
# Monday
# 60%
# the Central African Republic
# Kristy Kilburn
# Friday
# second-quarter
# Salvador
# 6.5 million
# Mexico
# Bitso
# bitco
# +4849
# Coinbase
# Musk
# Twitter
# Wednesday
# Tesladumped
# 75%
# last quarter
# Monday
# $1 trillion
# first
# June 13
# Matt Turner
# Insider Weekly
# today
# Ben Tobin
# GPV
# 23%
# year
# year
# YoY
# Q2
# 88%
# YoY
# the same period last year
# Satoshi Nakamoto
# British
# Peter McCormack
# 4
# Reuters
# Jack Dorsey-
# Block Inc
# Thursday
# the second quarter
# 5
# Reuters
# Jack Dorsey-
# Block Inc
# nearly 7%
# Friday
# Musk
# Twitter
# Wednesday
# Tesladumped
# 75%
# last quarter
# Coinbase
# 2022
# the year
# Mike Novogratz
# El Salvador
# chars]WASHINGTON
# Aug 3
# Reuters
# the U.S. Senate
# the Commodity Futures Trading Commission
# CFTC
# Celsius Network
# Tuesday
# U.S.
# U.S.
# Martin Glenn
# Manhatt
# $222 million
# 75%
# the Securities and Exchange Commission
# Block
# 2022
# James Howells
# UK
# Newport
# Wales
# approximately £150m
# thousands of tonnes
# this October
# GamesBeat Summit Next
# today
# Aug 11
# Reuters
# $3.12 trillion
# July
# 13%
# monthly
# CryptoCompare
# Thursday
# pri
# chars]July 28
# Reuters
# more than 56%
# this year
# PAULO
# July 25
# Reuters
# Brazilian
# XP Inc
# XP.O
# mid-August
# James Howells
# 8,000
# 2013
# the years
# chars]The Ethereum Merge
# 2014
# Merge
# second
# Scaramucci
# SkyBridge Capital
# one
# Bloomberg
# Legion Strategies
# November 2021
# Joe Hovde
# New York
# 6
# Newport
# Wales
# two
# Digital
# $554.7 million
# the second quarter
# 2021
# Monday
# downbeat
# Justin Sullivan
# Getty Images
# Nilay Patel
# earlier this year
# 8,000
# Mike Novogratz
# +2331 chars]In 2013
# Cleve Mesidor
# Department of Commerce
# Mesidor
# Thursday
# Tesla
# second-quarter
# as high as 10%
# Thursday
# Tesla
# Nasdaq
# Europe
# Wednesday
# Tesla
# second-quarter
# Thursday
# the Federal Reserve
# Nasdaq
# 10-year
# Treasury
# 49.99
# Euros
# Bitcoin
# 3
# US
# Robert Kiyosaki
# this week
# +1866 chars]US
# Thursday
# three
# more than 1%
# second
# the Federal Reserve
# as much as 75%
# JPMorgan
# Monday
# 36%
# 102%
# mid-June
# recent weeks
# Bank of America
# NFL
# Tom Brady
# 45-year-old
# NFT
# Yacht Club
# April
# Reuters
# the bleak winter
# Reuters
# the bleak winter
# chars]NEW YORK
# Aug 8
# Reuters
# first
# BitMEX
# Monday
# U.S.
# 9
# Reuters
# the second quarter
# Tuesday
# year
# chars]LONDON
# 3
# Reuters
# The European Union's
# +1324 chars]BANGKOK
# Thailand
# Friday
# late this year
# the middle of 2023
# chars]LONDON
# 12
# Reuters
# British
# ABDN.L
# digital
# Archax
# Thursday
# millions of dollars
# chars]NEW YORK
# Aug 16
# Reuters
# nearly 60%
# the first seven months of the year
# $1.9 billion
# November 2021
# two-thirds
# $3 trillion
# July 25
# Reuters
# China
# Sunday
# July 25
# Reuters
# Mexican
# Bitso
# one million
# Brazil
# about a year
# Brazil
# 2
# Reuters
# U.S.
# Tuesday
# Uber Technologies Inc
# 2016
# Alun John
# Fed
# last night
# July 2022
# more than $280 million
# around 8,000
# 5
# Spectra Logic
# the beginning of the day

# %%
# Concatenate all of the Ethereum text together
ethereum_text = (big_string_2)

# %%
# Run the NER processor on all of the text
doc_2 = nlp(ethereum_text)

# Add a title to the document
doc_2.user_data["NER Visualization - Ethereum"] = "NER Visualization - Ethereum"

# %%
# Render the visualization
displacy.render(doc_2, style='ent')
# Out:
# </br> (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>, but that's not stopping
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Instagram
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  from doubling down on digital collectibles. After a test launch in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>, the app is expanding its
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NF
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# … [+1097 chars]It's
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a day of the week ending
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br> in the cryptocurrency world.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Securities and Exchange Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has charged
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  peopl… [+1855 chars]Less than
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  into its soft launch,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GameStops
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  NFT marketplace is already courting controversy. Among the NFTs listed on the platform is an artwork called
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Falling Man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Web3 … [+1429
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chars]The Ethereum Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  is significant, and not just for people who own crypto. In the works in one form or another since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the long-delayed
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Merge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  will see the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  biggest blockchain reduce its car… [+10658 chars]Developers have picked a number of so-called total terminal difficulty required of the final block mined in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  before the network switches to new software. Figuring out the exact date range whe… [+1084 chars]Ethereum will improve upon its scalability after the completion of the so-called surge, co-founder
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vitalik Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>At
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ethereum Community Conference
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , he addressed overall… [+1344 chars]BANGKOK, Aug
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) - Crypto exchange Zipmex will release
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum and Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  tokens from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-alig
